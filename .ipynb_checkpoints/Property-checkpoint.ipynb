# %%
from concurrent.futures import ThreadPoolExecutor, ProcessPoolExecutor, as_completed
import pandas as pd
import requests
import time
import os
from multiprocessing import Pool
import random

class Property:
    def __init__(self, address, postcode, buurt, woonplaats, huisnummer, count):
        self.address = address
        self.postcode = postcode
        self.buurt = buurt
        self.woonplaats = woonplaats
        self.huisnummer = huisnummer
        self.count = count
        self.session = requests.Session()
        self.session.headers.update({'User-Agent': 'Mozilla/5.0'})



    def get_address_ids(self, complete_address):
        """Retrieve address IDs with a batch request if possible."""
        
        url = "https://api.pdok.nl/bzk/locatieserver/search/v3_1/suggest"
        params = {"q": complete_address}


        try:
            response = self.session.get(url, params=params, timeout=5)
            #response = request.get(url, params=params, timeout=5)
            response.raise_for_status()
            data = response.json()
            return [doc.get("id", "") for doc in data.get("response", {}).get("docs", [])]
        
        except (requests.RequestException, ValueError) as ex:
            print(f"Error retrieving address ID: {ex}")
            return None

    def get_correct_addressID(self, complete_address):
        """Obtain correct address IDs, leveraging more threads and reducing retries."""
        
        _ids = self.get_address_ids(complete_address)
        if not _ids:
            return None
        
        url = "https://api.pdok.nl/bzk/locatieserver/search/v3_1/lookup"
        address_data = {'nummeraanduiding_ids': [], 'adresseerbaarobject_ids': []}

        with ThreadPoolExecutor(max_workers=5) as executor:
            futures = [executor.submit(self.fetch_address_data, url, _id) for _id in _ids]
            for future in as_completed(futures):
                data = future.result()

                # Meassurement for getting only the corresponding id. Rijnlaan 1-BSA, 3522BA Utrecht
                if data.get("weergavenaam") == f'{self.address.split(" ")[0]} {self.huisnummer}, {self.postcode} {self.woonplaats}':
                    #print(f'Weergavenaam: {data.get("weergavenaam")}')
                    
                    nummeraanduiding_id = data.get("nummeraanduiding_id")
                    adresseerbaarobject_id = data.get("adresseerbaarobject_id")
                    
                    if nummeraanduiding_id and adresseerbaarobject_id:
                        address_data["nummeraanduiding_ids"].append(nummeraanduiding_id)
                        address_data["adresseerbaarobject_ids"].append(adresseerbaarobject_id)
                        
        return address_data

    def fetch_address_data(self, url, _id):
        """Helper to fetch data for each address ID."""
        params = {"id": _id}
        try:
            response = self.session.get(url, params=params, timeout=5)
            #response = requests.get(url, params=params, timeout=5)
            response.raise_for_status()
            return response.json().get("response", {}).get("docs", [{}])[0]
        except requests.RequestException as e:
            print(f"Request failed for {self.address} with error: {e}")
            return {}

    def get_woz_values(self, _ids):
        headers = {
            'sec-ch-ua-platform': '"Linux"',
            'Referer': '',
            'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
            'Accept': 'application/json, text/plain, */*',
            'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
            'sec-ch-ua-mobile': '?0',
        }
        
        base_url = "https://api.kadaster.nl/lvwoz/wozwaardeloket-api/v1/wozwaarde/nummeraanduiding/"
        woz_values = {year: None for year in range(2014, 2024)}
        grondoppervlakte = [None]  # Use list to hold reference for mutability
        max_retries = 4
        
        with ThreadPoolExecutor(max_workers=5) as executor:
            futures = [executor.submit(self.fetch_woz_value, base_url, _id, woz_values, grondoppervlakte) for _id in _ids]
            for future in as_completed(futures):
                future.result()
        
        return woz_values, grondoppervlakte[0]



    def fetch_woz_value(self, base_url, _id, woz_values, grondoppervlakte):
        attempt = 0
        while attempt < 4:
            try:
                response = self.session.get(f"{base_url}{_id}", timeout=5)
                #response = requests.get(url, timeout=5)
                #response = requests.get(f"{base_url}{_id}", timeout=5)
                if response.status_code == 429:
                    # wait_time = min(60, 2 ** attempt + random.uniform(0, 1))
                    # print(f"Rate limited. Waiting for {wait_time:.2f} seconds...")
                    # time.sleep(wait_time)
                    # attempt += 1
                    # continue

                    wait_time = min(60, (2 ** attempt) + random.uniform(0, 2 ** attempt))
                    print(f"Rate limited. Waiting for {wait_time:.2f} seconds...")
                    time.sleep(wait_time)
                    attempt += 1
                    continue
                
                response.raise_for_status()
                data = response.json()

                # Check wich if statements are nodig
                if not data:
                    print("Data is empty:", data)
                    
                if 'wozWaarden' not in data or not data['wozWaarden']:
                    print(f"No WOZ values found for ID {_id}, skipping.")
                    return False

                for item in data['wozWaarden']:
                    year = int(item['peildatum'][:4])
                    if 2014 <= year <= 2023:
                        woz_values[year] = item['vastgesteldeWaarde']
                       
                # Update grondoppervlakte if not yet set
                if grondoppervlakte[0] is None:
                    grondoppervlakte[0] = data['wozObject'].get('grondoppervlakte', None)
                
                return True
                
            except requests.exceptions.RequestException as e:
                print(f"Request failed for {_id} with error: {e} woz error for adress {self.address}")
                attempt += 1
                if attempt >= 4:
                    print("Maximum retries reached. Skipping this ID.")
                    return False
    

    def get_other_features(self, _ids):
        """Fetch additional features such as bouwjaar and oppervlakte."""
        features = {}
        with ThreadPoolExecutor(max_workers=10) as executor:
            futures = [executor.submit(self.fetch_other_feature, _id) for _id in _ids]
            for future in as_completed(futures):
                result = future.result()
                if result:
                    features.update(result)
        return features
        

    def fetch_other_feature(self, _id: str):
        headers = {
            'Accept': 'application/json, text/plain, */*',
            'User-Agent': 'Mozilla/5.0',
        }
        params = {'service': 'WFS'}
        features = {}

        data = (
            f'<wfs:GetFeature xmlns:wfs="http://www.opengis.net/wfs" '
            f'service="WFS" version="1.1.0" xsi:schemaLocation="http://www.opengis.net/wfs '
            f'http://schemas.opengis.net/wfs/1.0.0/WFS-transaction.xsd" '
            f'xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" outputFormat="application/json">'
            f'<wfs:Query typeName="verblijfsobject" xmlns:null="http://bag.geonovum.nl">'
            f'<ogc:Filter xmlns:ogc="http://www.opengis.net/ogc">'
            f'<ogc:PropertyIsEqualTo>'
            f'<ogc:PropertyName>identificatie</ogc:PropertyName>'
            f'<ogc:Literal>0{int(_id)}</ogc:Literal>'
            f'</ogc:PropertyIsEqualTo>'
            f'</ogc:Filter>'
            f'</wfs:Query>'
            f'</wfs:GetFeature>'
        )

        # try:
        #     response = requests.post(
        #         'https://service.pdok.nl/lv/bag/wfs/v2_0',
        #         params=params,
        #         headers=headers,
        #         data=data,
        #         timeout=5
        #     )
        try:
            response = self.session.post(
                'https://service.pdok.nl/lv/bag/wfs/v2_0',
                params=params,
                headers=headers,
                data=data,
                timeout=5
            )
            
            response.raise_for_status()

            if response.headers.get("Content-Type") == "application/json":
                data = response.json()
                
                if 'features' in data and data['features']:
                    feature_data = data['features'][0]['properties']
                    return {
                        'gebruiksdoel': feature_data.get('gebruiksdoel'),
                        'bouwjaar': feature_data.get('bouwjaar'),
                        'oppervlakte': feature_data.get('oppervlakte')
                    }
                
        except requests.exceptions.RequestException as ex:
            print(f"Request failed for ID {self.address} with error: {ex}, peoepepdepde")
            return None
            
        return {}

    def to_data(self):
        complete_address = f'{self.address} {self.postcode} {self.woonplaats}'
        
        print(f'Address being processed: {complete_address}, Property count: {self.count}')
        
        ids = self.get_correct_addressID(complete_address)
        
        if not ids:
            modified_address = f'{self.address.split(" ")[0]} {self.huisnummer}, {self.postcode} {self.woonplaats}'
            ids = self.get_correct_addressID(modified_address)

            if not ids:
                return None  # Empty DataFrame if no IDs

        #print(ids)

        # Other features
        other_features = self.get_other_features(ids["adresseerbaarobject_ids"])

        # Check if "gebruiksdoel" is "woonfunctie"; if not, skip this property
        if other_features.get("gebruiksdoel") != "woonfunctie":
            print(f"Skipping property at {self.address} as 'gebruiksdoel' is not 'woonfunctie'")
            return None  # Return an empty DataFrame to indicate skipping

        # WOZ values from 2014 to 2023
        woz_values, grondoppervlakte = self.get_woz_values(ids["nummeraanduiding_ids"])

        # When there aren't any woz values for the particular property, then skip
        if sum(1 for year in woz_values if woz_values.get(year) is None) == 10:   # Adjust for min number of woz_values
            print(f'{self.address}: does not have any woz values')
            return None

        else: 
            data = {
                "address": self.address,
                "buurt": self.buurt,
                "bouwjaar": other_features.get("bouwjaar"),
                "grondoppervlakte": grondoppervlakte,
                "oppervlakte": other_features.get("oppervlakte"),
                **{f"woz_{year}": woz_values.get(year) for year in range(2014, 2024)},
            }
            #print(data)

    
        return data

# %%
def initialize_csv(file_path: str):
    # Define the columns as per the specified labels
    columns = [
        "address", "buurt", "bouwjaar", "grondoppervlakte", "oppervlakte",
        "woz_2014", "woz_2015", "woz_2016", "woz_2017", "woz_2018",
        "woz_2019", "woz_2020", "woz_2021", "woz_2022", "woz_2023"
    ]

    # Create an empty DataFrame with these columns
    df = pd.DataFrame(columns=columns)

    # Save to CSV
    df.to_csv(file_path, index=False)
    print(f"Initialized CSV at: {file_path}")

file_path = '/home/wouter/Documents/Scriptie/csv property/property_data.csv'
initialize_csv(file_path)
# Out:
# Initialized CSV at: /home/wouter/Documents/Scriptie/csv property/property_data.csv

# %%
# Initialize CSV if not already initialized
file_path = '/home/wouter/Documents/Scriptie/csv property/property_data.csv'

# %%
import time

def save_property_to_csv(dataframe):
    start_time = time.time()  # Use time.time() for measuring elapsed time
    dict_data = []
    processed_count = 0
    
    # Iterate through each row in the filtered DataFrame
    for _, row in dataframe.iterrows():
        processed_count += 1
        address = f"{row['straat']} {str(row['huisnummer']).zfill(5)}"
            
        # Create a Property instance for each row
        property_instance = Property(address, row['postcode'], row['buurt'], row['woonplaats'], row['huisnummer'], processed_count)
        property_data = property_instance.to_data()

        if property_data:  # Only add valid data
            dict_data.append(property_data)
            
    if dict_data:
        pd.DataFrame(dict_data).to_csv(file_path, mode='a', header=not os.path.exists(file_path), index=False)
    
    print(f"Time taken: {time.time() - start_time} seconds")  # Print elapsed time
    return processed_count

# %% [markdown]
# ## Test with property class

# %%
import pandas as pd

file = open('utrecht_addresses.csv')
file = 'utrecht_addresses.csv'
utrecht_df = pd.read_csv(file)
display(utrecht_df.head())
# Out:
#   postcode huisnummer               straat  \
# 0   3511KZ          1     3e Buurkerksteeg
# 1   3511JH          1    Achter Clarenburg
# 2   3511MR          1  Albert Verweystraat
# 3   3511LM          1       Alendorpstraat
# 4   3511LM       1-BS       Alendorpstraat
#
#                                             buurt                wijk  \
# 0  Lange Elisabethstraat, Mariaplaats en omgeving  Wijk 06 Binnenstad
# 1  Lange Elisabethstraat, Mariaplaats en omgeving  Wijk 06 Binnenstad
# 2                                  Hooch Boulandt  Wijk 06 Binnenstad
# 3  Lange Elisabethstraat, Mariaplaats en omgeving  Wijk 06 Binnenstad
# 4  Lange Elisabethstraat, Mariaplaats en omgeving  Wijk 06 Binnenstad
#
#   woonplaats gemeente provincie   latitude  longitude
# 0    Utrecht  Utrecht   Utrecht  52.090449   5.118523
# 1    Utrecht  Utrecht   Utrecht  52.090584   5.116154
# 2    Utrecht  Utrecht   Utrecht  52.082053   5.120199
# 3    Utrecht  Utrecht   Utrecht  52.089463   5.118824
# 4    Utrecht  Utrecht   Utrecht  52.089475   5.118816

# %%
jaar_df = utrecht_df[(utrecht_df['buurt'] == 'Transwijk-Noord')]# | #(utrecht_df['buurt'] == 'Bedrijvengebied Strijkviertel') | (utrecht_df['buurt'] == 'Bedrijventerrein Lageweide')] #| (utrecht_df['buurt'] == 'Transwijk-Noord')]# | (utrecht_df['buurt'] == 'Het Zand-West')]

print(len(jaar_df))
# Out:
# 3402

# %%
save_property_to_csv(jaar_df)
# Out:
# Address being processed: Admiraal Helfrichlaan 00001 3527KV Utrecht, Property count: 1
# Skipping property at Admiraal Helfrichlaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Asserlaan 00001 3527VZ Utrecht, Property count: 2
# Address being processed: Benschoplaan 00001 3527XV Utrecht, Property count: 3
# Address being processed: Bertha von Suttnerlaan 00001 3527WC Utrecht, Property count: 4
# Skipping property at Bertha von Suttnerlaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Cornelia Moeslaan 00001 3527MG Utrecht, Property count: 5
# Skipping property at Cornelia Moeslaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: De Louterlaan 00001 3527KM Utrecht, Property count: 6
# Skipping property at De Louterlaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Egginklaan 00001 3527XP Utrecht, Property count: 7
# Address being processed: Geertje Zijlstrahof 00001 3527LW Utrecht, Property count: 8
# Skipping property at Geertje Zijlstrahof 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Grebbeberglaan 00001 3527VX Utrecht, Property count: 9
# Skipping property at Grebbeberglaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Greet Brinkhuispromenade 00001 3527LR Utrecht, Property count: 10
# Skipping property at Greet Brinkhuispromenade 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Hebe Kohlbruggeweg 00001 3527MD Utrecht, Property count: 11
# Skipping property at Hebe Kohlbruggeweg 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Koningin Wilhelminalaan 00001 3527LA Utrecht, Property count: 12
# Skipping property at Koningin Wilhelminalaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Laan van Verzetsstrijders 00001 3527LP Utrecht, Property count: 13
# Skipping property at Laan van Verzetsstrijders 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 00001 3527KA Utrecht, Property count: 14
# Address being processed: Maria Parélaan 00001 3527LJ Utrecht, Property count: 15
# Skipping property at Maria Parélaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Moeder Teresalaan 00001 3527WB Utrecht, Property count: 16
# Skipping property at Moeder Teresalaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Oranje Vrijbuiterslaan 00001 3527LH Utrecht, Property count: 17
# Skipping property at Oranje Vrijbuiterslaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Paulina van Crombruggehof 00001 3527LS Utrecht, Property count: 18
# Skipping property at Paulina van Crombruggehof 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Petronella Ketelpromenade 00001 3527LT Utrecht, Property count: 19
# Skipping property at Petronella Ketelpromenade 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Petronella Mulderstraat 00001 3527LM Utrecht, Property count: 20
# Skipping property at Petronella Mulderstraat 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Postmalaan 00001 3527XX Utrecht, Property count: 21
# Address being processed: Stempelslaan 00001 3527XS Utrecht, Property count: 22
# Address being processed: Struyckenlaan 00001 3527KJ Utrecht, Property count: 23
# Address being processed: Telderslaan 00001 3527KD Utrecht, Property count: 24
# Address being processed: Truus van Lierlaan 00001 3527KZ Utrecht, Property count: 25
# Skipping property at Truus van Lierlaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Uniceflaan 00001 3527WX Utrecht, Property count: 26
# Skipping property at Uniceflaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Utrechts Kindercomitéstraat 00001 3527LV Utrecht, Property count: 27
# Skipping property at Utrechts Kindercomitéstraat 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Bijnkershoeklaan 00001 3527XA Utrecht, Property count: 28
# Skipping property at Van Bijnkershoeklaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Eysingalaan 00001 3527VA Utrecht, Property count: 29
# Skipping property at Van Eysingalaan 00001 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Grebbeberglaan 0001A 3527VX Utrecht, Property count: 30
# Skipping property at Grebbeberglaan 0001A as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 0001A 3527KA Utrecht, Property count: 31
# Address being processed: Grebbeberglaan 0001B 3527VX Utrecht, Property count: 32
# Skipping property at Grebbeberglaan 0001B as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Asserlaan 00002 3527VZ Utrecht, Property count: 33
# Address being processed: Beneluxlaan 00002 3527HT Utrecht, Property count: 34
# Error retrieving address ID: HTTPSConnectionPool(host='api.pdok.nl', port=443): Read timed out. (read timeout=5)
# Skipping property at Beneluxlaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Benschoplaan 00002 3527XW Utrecht, Property count: 35
# Address being processed: Bertha von Suttnerlaan 00002 3527WD Utrecht, Property count: 36
# Skipping property at Bertha von Suttnerlaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Cornelia Moeslaan 00002 3527MG Utrecht, Property count: 37
# Skipping property at Cornelia Moeslaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Egginklaan 00002 3527XR Utrecht, Property count: 38
# Address being processed: Elisabeth Brugsmapromenade 00002 3527MC Utrecht, Property count: 39
# Skipping property at Elisabeth Brugsmapromenade 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Florence Nightingalelaan 00002 3527WG Utrecht, Property count: 40
# Skipping property at Florence Nightingalelaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Geertje Zijlstrahof 00002 3527LW Utrecht, Property count: 41
# Skipping property at Geertje Zijlstrahof 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Hebe Kohlbruggeweg 00002 3527MD Utrecht, Property count: 42
# Skipping property at Hebe Kohlbruggeweg 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Johannes Beenlaan 00002 3527XM Utrecht, Property count: 43
# Skipping property at Johannes Beenlaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Krikkelaan 00002 3527XN Utrecht, Property count: 44
# Address being processed: Laan van Verzetsstrijders 00002 3527LP Utrecht, Property count: 45
# Skipping property at Laan van Verzetsstrijders 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Mien Temmingpromenade 00002 3527LX Utrecht, Property count: 46
# Skipping property at Mien Temmingpromenade 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Nel van der Speklaan 00002 3527LN Utrecht, Property count: 47
# Skipping property at Nel van der Speklaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Olof Palmelaan 00002 3527WH Utrecht, Property count: 48
# Skipping property at Olof Palmelaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Overste den Oudenlaan 00002 3527KW Utrecht, Property count: 49
# Skipping property at Overste den Oudenlaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Paulina van Crombruggehof 00002 3527LS Utrecht, Property count: 50
# Skipping property at Paulina van Crombruggehof 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Postmalaan 00002 3527XZ Utrecht, Property count: 51
# Address being processed: Raoul Wallenberglaan 00002 3527WL Utrecht, Property count: 52
# Skipping property at Raoul Wallenberglaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Stempelslaan 00002 3527XT Utrecht, Property count: 53
# Address being processed: Struyckenlaan 00002 3527KL Utrecht, Property count: 54
# Address being processed: Uniceflaan 00002 3527WS Utrecht, Property count: 55
# Address being processed: Utrechts Kindercomitéstraat 00002 3527LV Utrecht, Property count: 56
# Skipping property at Utrechts Kindercomitéstraat 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Bijnkershoeklaan 00002 3527XL Utrecht, Property count: 57
# Skipping property at Van Bijnkershoeklaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Eysingalaan 00002 3527VL Utrecht, Property count: 58
# Skipping property at Van Eysingalaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00002 3527JR Utrecht, Property count: 59
# Skipping property at Van Vollenhovenlaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Weerden Poelmanlaan 00002 3527KN Utrecht, Property count: 60
# Skipping property at Van Weerden Poelmanlaan 00002 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Beneluxlaan 0002B 3527HT Utrecht, Property count: 61
# Skipping property at Beneluxlaan 0002B as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Asserlaan 00003 3527VZ Utrecht, Property count: 62
# Skipping property at Asserlaan 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Benschoplaan 00003 3527XV Utrecht, Property count: 63
# Address being processed: Bertha von Suttnerlaan 00003 3527WC Utrecht, Property count: 64
# Skipping property at Bertha von Suttnerlaan 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Cornelia Moeslaan 00003 3527MG Utrecht, Property count: 65
# Skipping property at Cornelia Moeslaan 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: De Louterlaan 00003 3527KM Utrecht, Property count: 66
# Skipping property at De Louterlaan 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Egginklaan 00003 3527XP Utrecht, Property count: 67
# Address being processed: Geertje Zijlstrahof 00003 3527LW Utrecht, Property count: 68
# Skipping property at Geertje Zijlstrahof 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Greet Brinkhuispromenade 00003 3527LR Utrecht, Property count: 69
# Skipping property at Greet Brinkhuispromenade 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Hebe Kohlbruggeweg 00003 3527MD Utrecht, Property count: 70
# Skipping property at Hebe Kohlbruggeweg 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Koningin Wilhelminalaan 00003 3527LA Utrecht, Property count: 71
# Skipping property at Koningin Wilhelminalaan 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Laan van Verzetsstrijders 00003 3527LP Utrecht, Property count: 72
# Skipping property at Laan van Verzetsstrijders 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 00003 3527KA Utrecht, Property count: 73
# Address being processed: Maria Parélaan 00003 3527LJ Utrecht, Property count: 74
# Skipping property at Maria Parélaan 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Moeder Teresalaan 00003 3527WB Utrecht, Property count: 75
# Skipping property at Moeder Teresalaan 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Oranje Vrijbuiterslaan 00003 3527LH Utrecht, Property count: 76
# Skipping property at Oranje Vrijbuiterslaan 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Paulina van Crombruggehof 00003 3527LS Utrecht, Property count: 77
# Skipping property at Paulina van Crombruggehof 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Petronella Ketelpromenade 00003 3527LT Utrecht, Property count: 78
# Skipping property at Petronella Ketelpromenade 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Petronella Mulderstraat 00003 3527LM Utrecht, Property count: 79
# Skipping property at Petronella Mulderstraat 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Postmalaan 00003 3527XX Utrecht, Property count: 80
# Address being processed: Stempelslaan 00003 3527XS Utrecht, Property count: 81
# Address being processed: Struyckenlaan 00003 3527KJ Utrecht, Property count: 82
# Address being processed: Telderslaan 00003 3527KD Utrecht, Property count: 83
# Address being processed: Utrechts Kindercomitéstraat 00003 3527LV Utrecht, Property count: 84
# Skipping property at Utrechts Kindercomitéstraat 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Bijnkershoeklaan 00003 3527XA Utrecht, Property count: 85
# Skipping property at Van Bijnkershoeklaan 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Eysingalaan 00003 3527VA Utrecht, Property count: 86
# Skipping property at Van Eysingalaan 00003 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Grebbeberglaan 0003A 3527VX Utrecht, Property count: 87
# Skipping property at Grebbeberglaan 0003A as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Grebbeberglaan 0003B 3527VX Utrecht, Property count: 88
# Skipping property at Grebbeberglaan 0003B as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Grebbeberglaan 0003C 3527VX Utrecht, Property count: 89
# Skipping property at Grebbeberglaan 0003C as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Asserlaan 00004 3527VZ Utrecht, Property count: 90
# Address being processed: Beneluxlaan 00004 3527HT Utrecht, Property count: 91
# Skipping property at Beneluxlaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Benschoplaan 00004 3527XW Utrecht, Property count: 92
# Address being processed: Bertha von Suttnerlaan 00004 3527WD Utrecht, Property count: 93
# Skipping property at Bertha von Suttnerlaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Cornelia Moeslaan 00004 3527MG Utrecht, Property count: 94
# Skipping property at Cornelia Moeslaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: De Louterlaan 00004 3527KM Utrecht, Property count: 95
# Skipping property at De Louterlaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Egginklaan 00004 3527XR Utrecht, Property count: 96
# Address being processed: Elisabeth Brugsmapromenade 00004 3527MC Utrecht, Property count: 97
# Skipping property at Elisabeth Brugsmapromenade 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Florence Nightingalelaan 00004 3527WG Utrecht, Property count: 98
# Skipping property at Florence Nightingalelaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Geertje Zijlstrahof 00004 3527LW Utrecht, Property count: 99
# Skipping property at Geertje Zijlstrahof 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Grebbeberglaan 00004 3527VX Utrecht, Property count: 100
# Skipping property at Grebbeberglaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Hebe Kohlbruggeweg 00004 3527MD Utrecht, Property count: 101
# Skipping property at Hebe Kohlbruggeweg 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Johannes Beenlaan 00004 3527XM Utrecht, Property count: 102
# Skipping property at Johannes Beenlaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Krikkelaan 00004 3527XN Utrecht, Property count: 103
# Address being processed: Laan van Verzetsstrijders 00004 3527LP Utrecht, Property count: 104
# Skipping property at Laan van Verzetsstrijders 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 00004 3527KC Utrecht, Property count: 105
# Address being processed: Mien Temmingpromenade 00004 3527LX Utrecht, Property count: 106
# Skipping property at Mien Temmingpromenade 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Nel van der Speklaan 00004 3527LN Utrecht, Property count: 107
# Skipping property at Nel van der Speklaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Olof Palmelaan 00004 3527WH Utrecht, Property count: 108
# Skipping property at Olof Palmelaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Paulina van Crombruggehof 00004 3527LS Utrecht, Property count: 109
# Skipping property at Paulina van Crombruggehof 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Postmalaan 00004 3527XZ Utrecht, Property count: 110
# Address being processed: Raoul Wallenberglaan 00004 3527WL Utrecht, Property count: 111
# Skipping property at Raoul Wallenberglaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Stempelslaan 00004 3527XT Utrecht, Property count: 112
# Address being processed: Struyckenlaan 00004 3527KL Utrecht, Property count: 113
# Skipping property at Struyckenlaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Telderslaan 00004 3527KG Utrecht, Property count: 114
# Address being processed: Uniceflaan 00004 3527WS Utrecht, Property count: 115
# Address being processed: Utrechts Kindercomitéstraat 00004 3527LV Utrecht, Property count: 116
# Skipping property at Utrechts Kindercomitéstraat 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Bijnkershoeklaan 00004 3527XL Utrecht, Property count: 117
# Skipping property at Van Bijnkershoeklaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Eysingalaan 00004 3527VL Utrecht, Property count: 118
# Skipping property at Van Eysingalaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00004 3527JR Utrecht, Property count: 119
# Skipping property at Van Vollenhovenlaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Weerden Poelmanlaan 00004 3527KN Utrecht, Property count: 120
# Skipping property at Van Weerden Poelmanlaan 00004 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Beneluxlaan 0004A 3527HT Utrecht, Property count: 121
# Skipping property at Beneluxlaan 0004A as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Beneluxlaan 0004B 3527HT Utrecht, Property count: 122
# Skipping property at Beneluxlaan 0004B as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Asserlaan 00005 3527VZ Utrecht, Property count: 123
# Skipping property at Asserlaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Benschoplaan 00005 3527XV Utrecht, Property count: 124
# Address being processed: Bertha von Suttnerlaan 00005 3527WC Utrecht, Property count: 125
# Skipping property at Bertha von Suttnerlaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Cornelia Moeslaan 00005 3527MG Utrecht, Property count: 126
# Skipping property at Cornelia Moeslaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: De Louterlaan 00005 3527KM Utrecht, Property count: 127
# Skipping property at De Louterlaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Egginklaan 00005 3527XP Utrecht, Property count: 128
# Address being processed: Geertje Zijlstrahof 00005 3527LW Utrecht, Property count: 129
# Skipping property at Geertje Zijlstrahof 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Grebbeberglaan 00005 3527VX Utrecht, Property count: 130
# Skipping property at Grebbeberglaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Greet Brinkhuispromenade 00005 3527LR Utrecht, Property count: 131
# Skipping property at Greet Brinkhuispromenade 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Hebe Kohlbruggeweg 00005 3527MD Utrecht, Property count: 132
# Skipping property at Hebe Kohlbruggeweg 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Koningin Wilhelminalaan 00005 3527LA Utrecht, Property count: 133
# Skipping property at Koningin Wilhelminalaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Laan van Verzetsstrijders 00005 3527LP Utrecht, Property count: 134
# Skipping property at Laan van Verzetsstrijders 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 00005 3527KA Utrecht, Property count: 135
# Address being processed: Maria Parélaan 00005 3527LJ Utrecht, Property count: 136
# Skipping property at Maria Parélaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Moeder Teresalaan 00005 3527WB Utrecht, Property count: 137
# Skipping property at Moeder Teresalaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Oranje Vrijbuiterslaan 00005 3527LH Utrecht, Property count: 138
# Skipping property at Oranje Vrijbuiterslaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Overste den Oudenlaan 00005 3527KW Utrecht, Property count: 139
# Skipping property at Overste den Oudenlaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Paulina van Crombruggehof 00005 3527LS Utrecht, Property count: 140
# Skipping property at Paulina van Crombruggehof 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Petronella Ketelpromenade 00005 3527LT Utrecht, Property count: 141
# Skipping property at Petronella Ketelpromenade 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Petronella Mulderstraat 00005 3527LM Utrecht, Property count: 142
# Skipping property at Petronella Mulderstraat 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Postmalaan 00005 3527XX Utrecht, Property count: 143
# Address being processed: Stempelslaan 00005 3527XS Utrecht, Property count: 144
# Address being processed: Struyckenlaan 00005 3527KJ Utrecht, Property count: 145
# Address being processed: Telderslaan 00005 3527KD Utrecht, Property count: 146
# Address being processed: Utrechts Kindercomitéstraat 00005 3527LV Utrecht, Property count: 147
# Skipping property at Utrechts Kindercomitéstraat 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Bijnkershoeklaan 00005 3527XA Utrecht, Property count: 148
# Skipping property at Van Bijnkershoeklaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Eysingalaan 00005 3527VA Utrecht, Property count: 149
# Skipping property at Van Eysingalaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00005 3527JA Utrecht, Property count: 150
# Skipping property at Van Vollenhovenlaan 00005 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Grebbeberglaan 0005A 3527VX Utrecht, Property count: 151
# Skipping property at Grebbeberglaan 0005A as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 0005A 3527KA Utrecht, Property count: 152
# Address being processed: Admiraal Helfrichlaan 00006 3527KV Utrecht, Property count: 153
# Skipping property at Admiraal Helfrichlaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Asserlaan 00006 3527VZ Utrecht, Property count: 154
# Skipping property at Asserlaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Beneluxlaan 00006 3527HT Utrecht, Property count: 155
# Skipping property at Beneluxlaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Benschoplaan 00006 3527XW Utrecht, Property count: 156
# Address being processed: Bertha von Suttnerlaan 00006 3527WD Utrecht, Property count: 157
# Skipping property at Bertha von Suttnerlaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Cornelia Moeslaan 00006 3527MG Utrecht, Property count: 158
# Skipping property at Cornelia Moeslaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: De Louterlaan 00006 3527KM Utrecht, Property count: 159
# Skipping property at De Louterlaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Egginklaan 00006 3527XR Utrecht, Property count: 160
# Address being processed: Elisabeth Brugsmapromenade 00006 3527MC Utrecht, Property count: 161
# Skipping property at Elisabeth Brugsmapromenade 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Florence Nightingalelaan 00006 3527WG Utrecht, Property count: 162
# Skipping property at Florence Nightingalelaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Geertje Zijlstrahof 00006 3527LW Utrecht, Property count: 163
# Skipping property at Geertje Zijlstrahof 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Hebe Kohlbruggeweg 00006 3527MD Utrecht, Property count: 164
# Skipping property at Hebe Kohlbruggeweg 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Johannes Beenlaan 00006 3527XM Utrecht, Property count: 165
# Skipping property at Johannes Beenlaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Krikkelaan 00006 3527XN Utrecht, Property count: 166
# Address being processed: Laan van Verzetsstrijders 00006 3527LP Utrecht, Property count: 167
# Skipping property at Laan van Verzetsstrijders 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 00006 3527KC Utrecht, Property count: 168
# Address being processed: Mien Temmingpromenade 00006 3527LX Utrecht, Property count: 169
# Skipping property at Mien Temmingpromenade 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Nel van der Speklaan 00006 3527LN Utrecht, Property count: 170
# Skipping property at Nel van der Speklaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Olof Palmelaan 00006 3527WH Utrecht, Property count: 171
# Skipping property at Olof Palmelaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Paulina van Crombruggehof 00006 3527LS Utrecht, Property count: 172
# Skipping property at Paulina van Crombruggehof 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Postmalaan 00006 3527XZ Utrecht, Property count: 173
# Address being processed: Raoul Wallenberglaan 00006 3527WL Utrecht, Property count: 174
# Skipping property at Raoul Wallenberglaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Stempelslaan 00006 3527XT Utrecht, Property count: 175
# Address being processed: Struyckenlaan 00006 3527KL Utrecht, Property count: 176
# Skipping property at Struyckenlaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Telderslaan 00006 3527KG Utrecht, Property count: 177
# Address being processed: Uniceflaan 00006 3527WS Utrecht, Property count: 178
# Address being processed: Utrechts Kindercomitéstraat 00006 3527LV Utrecht, Property count: 179
# Skipping property at Utrechts Kindercomitéstraat 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Bijnkershoeklaan 00006 3527XL Utrecht, Property count: 180
# Skipping property at Van Bijnkershoeklaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Eysingalaan 00006 3527VL Utrecht, Property count: 181
# Skipping property at Van Eysingalaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00006 3527JR Utrecht, Property count: 182
# Skipping property at Van Vollenhovenlaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Weerden Poelmanlaan 00006 3527KN Utrecht, Property count: 183
# Skipping property at Van Weerden Poelmanlaan 00006 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Asserlaan 00007 3527VZ Utrecht, Property count: 184
# Address being processed: Benschoplaan 00007 3527XV Utrecht, Property count: 185
# Address being processed: Bertha von Suttnerlaan 00007 3527WC Utrecht, Property count: 186
# Skipping property at Bertha von Suttnerlaan 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Cornelia Moeslaan 00007 3527MG Utrecht, Property count: 187
# Skipping property at Cornelia Moeslaan 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: De Louterlaan 00007 3527KM Utrecht, Property count: 188
# Skipping property at De Louterlaan 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Egginklaan 00007 3527XP Utrecht, Property count: 189
# Address being processed: Geertje Zijlstrahof 00007 3527LW Utrecht, Property count: 190
# Skipping property at Geertje Zijlstrahof 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Grebbeberglaan 00007 3527VX Utrecht, Property count: 191
# Skipping property at Grebbeberglaan 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Greet Brinkhuispromenade 00007 3527LR Utrecht, Property count: 192
# Skipping property at Greet Brinkhuispromenade 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Hebe Kohlbruggeweg 00007 3527MD Utrecht, Property count: 193
# Skipping property at Hebe Kohlbruggeweg 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Koningin Wilhelminalaan 00007 3527LA Utrecht, Property count: 194
# Skipping property at Koningin Wilhelminalaan 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Laan van Verzetsstrijders 00007 3527LP Utrecht, Property count: 195
# Skipping property at Laan van Verzetsstrijders 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 00007 3527KA Utrecht, Property count: 196
# Address being processed: Maria Parélaan 00007 3527LJ Utrecht, Property count: 197
# Skipping property at Maria Parélaan 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Moeder Teresalaan 00007 3527WB Utrecht, Property count: 198
# Skipping property at Moeder Teresalaan 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Oranje Vrijbuiterslaan 00007 3527LH Utrecht, Property count: 199
# Skipping property at Oranje Vrijbuiterslaan 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Overste den Oudenlaan 00007 3527KW Utrecht, Property count: 200
# Skipping property at Overste den Oudenlaan 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Paulina van Crombruggehof 00007 3527LS Utrecht, Property count: 201
# Skipping property at Paulina van Crombruggehof 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Petronella Ketelpromenade 00007 3527LT Utrecht, Property count: 202
# Skipping property at Petronella Ketelpromenade 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Petronella Mulderstraat 00007 3527LM Utrecht, Property count: 203
# Skipping property at Petronella Mulderstraat 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Postmalaan 00007 3527XX Utrecht, Property count: 204
# Address being processed: Stempelslaan 00007 3527XS Utrecht, Property count: 205
# Address being processed: Struyckenlaan 00007 3527KJ Utrecht, Property count: 206
# Address being processed: Telderslaan 00007 3527KD Utrecht, Property count: 207
# Address being processed: Utrechts Kindercomitéstraat 00007 3527LV Utrecht, Property count: 208
# Skipping property at Utrechts Kindercomitéstraat 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Bijnkershoeklaan 00007 3527XA Utrecht, Property count: 209
# Skipping property at Van Bijnkershoeklaan 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Eysingalaan 00007 3527VA Utrecht, Property count: 210
# Skipping property at Van Eysingalaan 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00007 3527JA Utrecht, Property count: 211
# Skipping property at Van Vollenhovenlaan 00007 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00008 3527KV Utrecht, Property count: 212
# Skipping property at Admiraal Helfrichlaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Asserlaan 00008 3527VZ Utrecht, Property count: 213
# Address being processed: Beneluxlaan 00008 3527HT Utrecht, Property count: 214
# Skipping property at Beneluxlaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Benschoplaan 00008 3527XW Utrecht, Property count: 215
# Address being processed: Bertha von Suttnerlaan 00008 3527WD Utrecht, Property count: 216
# Skipping property at Bertha von Suttnerlaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Cornelia Moeslaan 00008 3527MG Utrecht, Property count: 217
# Skipping property at Cornelia Moeslaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: De Louterlaan 00008 3527KM Utrecht, Property count: 218
# Skipping property at De Louterlaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Egginklaan 00008 3527XR Utrecht, Property count: 219
# Address being processed: Elisabeth Brugsmapromenade 00008 3527MC Utrecht, Property count: 220
# Skipping property at Elisabeth Brugsmapromenade 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Florence Nightingalelaan 00008 3527WG Utrecht, Property count: 221
# Skipping property at Florence Nightingalelaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Geertje Zijlstrahof 00008 3527LW Utrecht, Property count: 222
# Skipping property at Geertje Zijlstrahof 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Hebe Kohlbruggeweg 00008 3527MD Utrecht, Property count: 223
# Skipping property at Hebe Kohlbruggeweg 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Johannes Beenlaan 00008 3527XM Utrecht, Property count: 224
# Skipping property at Johannes Beenlaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Krikkelaan 00008 3527XN Utrecht, Property count: 225
# Address being processed: Laan van Verzetsstrijders 00008 3527LP Utrecht, Property count: 226
# Skipping property at Laan van Verzetsstrijders 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 00008 3527KC Utrecht, Property count: 227
# Address being processed: Mien Temmingpromenade 00008 3527LX Utrecht, Property count: 228
# Skipping property at Mien Temmingpromenade 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Nel van der Speklaan 00008 3527LN Utrecht, Property count: 229
# Skipping property at Nel van der Speklaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Olof Palmelaan 00008 3527WH Utrecht, Property count: 230
# Skipping property at Olof Palmelaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Paulina van Crombruggehof 00008 3527LS Utrecht, Property count: 231
# Skipping property at Paulina van Crombruggehof 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Postmalaan 00008 3527XZ Utrecht, Property count: 232
# Address being processed: Raoul Wallenberglaan 00008 3527WL Utrecht, Property count: 233
# Skipping property at Raoul Wallenberglaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Stempelslaan 00008 3527XT Utrecht, Property count: 234
# Address being processed: Struyckenlaan 00008 3527KL Utrecht, Property count: 235
# Address being processed: Telderslaan 00008 3527KG Utrecht, Property count: 236
# Address being processed: Uniceflaan 00008 3527WS Utrecht, Property count: 237
# Address being processed: Utrechts Kindercomitéstraat 00008 3527LV Utrecht, Property count: 238
# Skipping property at Utrechts Kindercomitéstraat 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Bijnkershoeklaan 00008 3527XL Utrecht, Property count: 239
# Skipping property at Van Bijnkershoeklaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Eysingalaan 00008 3527VL Utrecht, Property count: 240
# Skipping property at Van Eysingalaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00008 3527JR Utrecht, Property count: 241
# Skipping property at Van Vollenhovenlaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Weerden Poelmanlaan 00008 3527KN Utrecht, Property count: 242
# Skipping property at Van Weerden Poelmanlaan 00008 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Bijnkershoeklaan 0008A 3527XL Utrecht, Property count: 243
# Skipping property at Van Bijnkershoeklaan 0008A as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Asserlaan 00009 3527VZ Utrecht, Property count: 244
# Address being processed: Benschoplaan 00009 3527XV Utrecht, Property count: 245
# Address being processed: Bertha von Suttnerlaan 00009 3527WC Utrecht, Property count: 246
# Skipping property at Bertha von Suttnerlaan 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Cornelia Moeslaan 00009 3527MG Utrecht, Property count: 247
# Skipping property at Cornelia Moeslaan 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: De Louterlaan 00009 3527KM Utrecht, Property count: 248
# Skipping property at De Louterlaan 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Egginklaan 00009 3527XP Utrecht, Property count: 249
# Address being processed: Geertje Zijlstrahof 00009 3527LW Utrecht, Property count: 250
# Skipping property at Geertje Zijlstrahof 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Greet Brinkhuispromenade 00009 3527LR Utrecht, Property count: 251
# Skipping property at Greet Brinkhuispromenade 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Hebe Kohlbruggeweg 00009 3527MD Utrecht, Property count: 252
# Skipping property at Hebe Kohlbruggeweg 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Koningin Wilhelminalaan 00009 3527LA Utrecht, Property count: 253
# Skipping property at Koningin Wilhelminalaan 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Laan van Verzetsstrijders 00009 3527LP Utrecht, Property count: 254
# Skipping property at Laan van Verzetsstrijders 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 00009 3527KA Utrecht, Property count: 255
# Address being processed: Maria Parélaan 00009 3527LJ Utrecht, Property count: 256
# Skipping property at Maria Parélaan 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Moeder Teresalaan 00009 3527WB Utrecht, Property count: 257
# Skipping property at Moeder Teresalaan 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Oranje Vrijbuiterslaan 00009 3527LH Utrecht, Property count: 258
# Skipping property at Oranje Vrijbuiterslaan 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Overste den Oudenlaan 00009 3527KW Utrecht, Property count: 259
# Skipping property at Overste den Oudenlaan 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Paulina van Crombruggehof 00009 3527LS Utrecht, Property count: 260
# Skipping property at Paulina van Crombruggehof 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Petronella Ketelpromenade 00009 3527LT Utrecht, Property count: 261
# Skipping property at Petronella Ketelpromenade 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Petronella Mulderstraat 00009 3527LM Utrecht, Property count: 262
# Skipping property at Petronella Mulderstraat 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Postmalaan 00009 3527XX Utrecht, Property count: 263
# Address being processed: Stempelslaan 00009 3527XS Utrecht, Property count: 264
# Address being processed: Struyckenlaan 00009 3527KJ Utrecht, Property count: 265
# Address being processed: Telderslaan 00009 3527KD Utrecht, Property count: 266
# Address being processed: Utrechts Kindercomitéstraat 00009 3527LV Utrecht, Property count: 267
# Skipping property at Utrechts Kindercomitéstraat 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Bijnkershoeklaan 00009 3527XA Utrecht, Property count: 268
# Skipping property at Van Bijnkershoeklaan 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Eysingalaan 00009 3527VA Utrecht, Property count: 269
# Skipping property at Van Eysingalaan 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00009 3527JA Utrecht, Property count: 270
# Skipping property at Van Vollenhovenlaan 00009 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Grebbeberglaan 0009A 3527VX Utrecht, Property count: 271
# Skipping property at Grebbeberglaan 0009A as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 0009A 3527KA Utrecht, Property count: 272
# Address being processed: Grebbeberglaan 0009B 3527VX Utrecht, Property count: 273
# Skipping property at Grebbeberglaan 0009B as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Grebbeberglaan 0009C 3527VX Utrecht, Property count: 274
# Skipping property at Grebbeberglaan 0009C as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Asserlaan 00010 3527VZ Utrecht, Property count: 275
# Address being processed: Beneluxlaan 00010 3527HT Utrecht, Property count: 276
# Address being processed: Benschoplaan 00010 3527XW Utrecht, Property count: 277
# Address being processed: Bertha von Suttnerlaan 00010 3527WD Utrecht, Property count: 278
# Skipping property at Bertha von Suttnerlaan 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Cornelia Moeslaan 00010 3527MG Utrecht, Property count: 279
# Skipping property at Cornelia Moeslaan 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: De Louterlaan 00010 3527KM Utrecht, Property count: 280
# Skipping property at De Louterlaan 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Egginklaan 00010 3527XR Utrecht, Property count: 281
# Address being processed: Elisabeth Brugsmapromenade 00010 3527MC Utrecht, Property count: 282
# Skipping property at Elisabeth Brugsmapromenade 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Florence Nightingalelaan 00010 3527WG Utrecht, Property count: 283
# Skipping property at Florence Nightingalelaan 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Hebe Kohlbruggeweg 00010 3527MD Utrecht, Property count: 284
# Skipping property at Hebe Kohlbruggeweg 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Johannes Beenlaan 00010 3527XM Utrecht, Property count: 285
# Skipping property at Johannes Beenlaan 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Krikkelaan 00010 3527XN Utrecht, Property count: 286
# Address being processed: Laan van Verzetsstrijders 00010 3527LP Utrecht, Property count: 287
# Skipping property at Laan van Verzetsstrijders 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 00010 3527KC Utrecht, Property count: 288
# Address being processed: Mien Temmingpromenade 00010 3527LX Utrecht, Property count: 289
# Skipping property at Mien Temmingpromenade 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Olof Palmelaan 00010 3527WH Utrecht, Property count: 290
# Skipping property at Olof Palmelaan 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Oranje Vrijbuiterskade 00010 3527LG Utrecht, Property count: 291
# Skipping property at Oranje Vrijbuiterskade 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Paulina van Crombruggehof 00010 3527LS Utrecht, Property count: 292
# Skipping property at Paulina van Crombruggehof 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Postmalaan 00010 3527XZ Utrecht, Property count: 293
# Address being processed: Raoul Wallenberglaan 00010 3527WL Utrecht, Property count: 294
# Skipping property at Raoul Wallenberglaan 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Stempelslaan 00010 3527XT Utrecht, Property count: 295
# Address being processed: Struyckenlaan 00010 3527KL Utrecht, Property count: 296
# Address being processed: Telderslaan 00010 3527KG Utrecht, Property count: 297
# Address being processed: Uniceflaan 00010 3527WS Utrecht, Property count: 298
# Address being processed: Utrechts Kindercomitéstraat 00010 3527LV Utrecht, Property count: 299
# Skipping property at Utrechts Kindercomitéstraat 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Bijnkershoeklaan 00010 3527XL Utrecht, Property count: 300
# Skipping property at Van Bijnkershoeklaan 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Eysingalaan 00010 3527VL Utrecht, Property count: 301
# Skipping property at Van Eysingalaan 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00010 3527JR Utrecht, Property count: 302
# Skipping property at Van Vollenhovenlaan 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Weerden Poelmanlaan 00010 3527KN Utrecht, Property count: 303
# Skipping property at Van Weerden Poelmanlaan 00010 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Asserlaan 00011 3527VZ Utrecht, Property count: 304
# Address being processed: Benschoplaan 00011 3527XV Utrecht, Property count: 305
# Address being processed: Bertha von Suttnerlaan 00011 3527WC Utrecht, Property count: 306
# Skipping property at Bertha von Suttnerlaan 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Cornelia Moeslaan 00011 3527MG Utrecht, Property count: 307
# Skipping property at Cornelia Moeslaan 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: De Louterlaan 00011 3527KM Utrecht, Property count: 308
# Skipping property at De Louterlaan 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Egginklaan 00011 3527XP Utrecht, Property count: 309
# Address being processed: Grebbeberglaan 00011 3527VX Utrecht, Property count: 310
# Skipping property at Grebbeberglaan 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Greet Brinkhuispromenade 00011 3527LR Utrecht, Property count: 311
# Skipping property at Greet Brinkhuispromenade 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Hebe Kohlbruggeweg 00011 3527MD Utrecht, Property count: 312
# Skipping property at Hebe Kohlbruggeweg 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Koningin Wilhelminalaan 00011 3527LA Utrecht, Property count: 313
# Skipping property at Koningin Wilhelminalaan 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Laan van Verzetsstrijders 00011 3527LP Utrecht, Property count: 314
# Skipping property at Laan van Verzetsstrijders 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Loderlaan 00011 3527KA Utrecht, Property count: 315
# Address being processed: Maria Parélaan 00011 3527LJ Utrecht, Property count: 316
# Skipping property at Maria Parélaan 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Moeder Teresalaan 00011 3527WB Utrecht, Property count: 317
# Skipping property at Moeder Teresalaan 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Oranje Vrijbuiterslaan 00011 3527LH Utrecht, Property count: 318
# Skipping property at Oranje Vrijbuiterslaan 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Paulina van Crombruggehof 00011 3527LS Utrecht, Property count: 319
# Skipping property at Paulina van Crombruggehof 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Petronella Ketelpromenade 00011 3527LT Utrecht, Property count: 320
# Skipping property at Petronella Ketelpromenade 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Postmalaan 00011 3527XX Utrecht, Property count: 321
# Address being processed: Stempelslaan 00011 3527XS Utrecht, Property count: 322
# Address being processed: Struyckenlaan 00011 3527KJ Utrecht, Property count: 323
# Address being processed: Telderslaan 00011 3527KD Utrecht, Property count: 324
# Address being processed: Utrechts Kindercomitéstraat 00011 3527LV Utrecht, Property count: 325
# Skipping property at Utrechts Kindercomitéstraat 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Bijnkershoeklaan 00011 3527XA Utrecht, Property count: 326
# Skipping property at Van Bijnkershoeklaan 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Eysingalaan 00011 3527VA Utrecht, Property count: 327
# Skipping property at Van Eysingalaan 00011 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00011 3527JA Utrecht, Property count: 328
# ...
# Skipping property at Admiraal Helfrichlaan 00555 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00555 3527JM Utrecht, Property count: 3313
# Skipping property at Van Vollenhovenlaan 00555 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00557 3527KV Utrecht, Property count: 3314
# Skipping property at Admiraal Helfrichlaan 00557 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00557 3527JM Utrecht, Property count: 3315
# Skipping property at Van Vollenhovenlaan 00557 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00559 3527KV Utrecht, Property count: 3316
# Skipping property at Admiraal Helfrichlaan 00559 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00559 3527JM Utrecht, Property count: 3317
# Skipping property at Van Vollenhovenlaan 00559 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00561 3527KV Utrecht, Property count: 3318
# Skipping property at Admiraal Helfrichlaan 00561 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00561 3527JM Utrecht, Property count: 3319
# Skipping property at Van Vollenhovenlaan 00561 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00563 3527KV Utrecht, Property count: 3320
# Skipping property at Admiraal Helfrichlaan 00563 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00563 3527JM Utrecht, Property count: 3321
# Skipping property at Van Vollenhovenlaan 00563 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00565 3527KV Utrecht, Property count: 3322
# Skipping property at Admiraal Helfrichlaan 00565 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00565 3527JM Utrecht, Property count: 3323
# Skipping property at Van Vollenhovenlaan 00565 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00567 3527KV Utrecht, Property count: 3324
# Skipping property at Admiraal Helfrichlaan 00567 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00567 3527JM Utrecht, Property count: 3325
# Skipping property at Van Vollenhovenlaan 00567 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00569 3527KV Utrecht, Property count: 3326
# Skipping property at Admiraal Helfrichlaan 00569 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00569 3527JM Utrecht, Property count: 3327
# Skipping property at Van Vollenhovenlaan 00569 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00571 3527KV Utrecht, Property count: 3328
# Skipping property at Admiraal Helfrichlaan 00571 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00571 3527JM Utrecht, Property count: 3329
# Skipping property at Van Vollenhovenlaan 00571 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00573 3527KV Utrecht, Property count: 3330
# Skipping property at Admiraal Helfrichlaan 00573 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00573 3527JM Utrecht, Property count: 3331
# Skipping property at Van Vollenhovenlaan 00573 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00575 3527KV Utrecht, Property count: 3332
# Skipping property at Admiraal Helfrichlaan 00575 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00575 3527JM Utrecht, Property count: 3333
# Skipping property at Van Vollenhovenlaan 00575 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00577 3527KV Utrecht, Property count: 3334
# Skipping property at Admiraal Helfrichlaan 00577 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00577 3527JM Utrecht, Property count: 3335
# Skipping property at Van Vollenhovenlaan 00577 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00579 3527KV Utrecht, Property count: 3336
# Skipping property at Admiraal Helfrichlaan 00579 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00579 3527JN Utrecht, Property count: 3337
# Skipping property at Van Vollenhovenlaan 00579 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00581 3527KV Utrecht, Property count: 3338
# Skipping property at Admiraal Helfrichlaan 00581 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00581 3527JN Utrecht, Property count: 3339
# Skipping property at Van Vollenhovenlaan 00581 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00583 3527KV Utrecht, Property count: 3340
# Skipping property at Admiraal Helfrichlaan 00583 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00583 3527JN Utrecht, Property count: 3341
# Skipping property at Van Vollenhovenlaan 00583 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00585 3527KV Utrecht, Property count: 3342
# Skipping property at Admiraal Helfrichlaan 00585 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00585 3527JN Utrecht, Property count: 3343
# Skipping property at Van Vollenhovenlaan 00585 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00587 3527KV Utrecht, Property count: 3344
# Skipping property at Admiraal Helfrichlaan 00587 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00587 3527JN Utrecht, Property count: 3345
# Skipping property at Van Vollenhovenlaan 00587 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00589 3527KV Utrecht, Property count: 3346
# Skipping property at Admiraal Helfrichlaan 00589 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00589 3527JN Utrecht, Property count: 3347
# Skipping property at Van Vollenhovenlaan 00589 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00591 3527KV Utrecht, Property count: 3348
# Skipping property at Admiraal Helfrichlaan 00591 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00591 3527JN Utrecht, Property count: 3349
# Skipping property at Van Vollenhovenlaan 00591 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00593 3527KV Utrecht, Property count: 3350
# Skipping property at Admiraal Helfrichlaan 00593 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00593 3527JN Utrecht, Property count: 3351
# Skipping property at Van Vollenhovenlaan 00593 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00595 3527KV Utrecht, Property count: 3352
# Skipping property at Admiraal Helfrichlaan 00595 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00595 3527JN Utrecht, Property count: 3353
# Skipping property at Van Vollenhovenlaan 00595 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00597 3527KV Utrecht, Property count: 3354
# Skipping property at Admiraal Helfrichlaan 00597 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00597 3527JN Utrecht, Property count: 3355
# Skipping property at Van Vollenhovenlaan 00597 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00599 3527KV Utrecht, Property count: 3356
# Skipping property at Admiraal Helfrichlaan 00599 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00599 3527JN Utrecht, Property count: 3357
# Skipping property at Van Vollenhovenlaan 00599 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00601 3527KV Utrecht, Property count: 3358
# Skipping property at Admiraal Helfrichlaan 00601 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00601 3527JN Utrecht, Property count: 3359
# Skipping property at Van Vollenhovenlaan 00601 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00603 3527KV Utrecht, Property count: 3360
# Skipping property at Admiraal Helfrichlaan 00603 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00603 3527JN Utrecht, Property count: 3361
# Skipping property at Van Vollenhovenlaan 00603 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00605 3527KV Utrecht, Property count: 3362
# Skipping property at Admiraal Helfrichlaan 00605 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00605 3527JN Utrecht, Property count: 3363
# Skipping property at Van Vollenhovenlaan 00605 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00607 3527KV Utrecht, Property count: 3364
# Skipping property at Admiraal Helfrichlaan 00607 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00607 3527JN Utrecht, Property count: 3365
# Skipping property at Van Vollenhovenlaan 00607 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00609 3527KV Utrecht, Property count: 3366
# Skipping property at Admiraal Helfrichlaan 00609 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00609 3527JN Utrecht, Property count: 3367
# Skipping property at Van Vollenhovenlaan 00609 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00611 3527KV Utrecht, Property count: 3368
# Skipping property at Admiraal Helfrichlaan 00611 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00611 3527JN Utrecht, Property count: 3369
# Skipping property at Van Vollenhovenlaan 00611 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00613 3527KV Utrecht, Property count: 3370
# Skipping property at Admiraal Helfrichlaan 00613 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00613 3527JN Utrecht, Property count: 3371
# Skipping property at Van Vollenhovenlaan 00613 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00615 3527KV Utrecht, Property count: 3372
# Skipping property at Admiraal Helfrichlaan 00615 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00615 3527JN Utrecht, Property count: 3373
# Skipping property at Van Vollenhovenlaan 00615 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00617 3527KV Utrecht, Property count: 3374
# Skipping property at Admiraal Helfrichlaan 00617 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00617 3527JN Utrecht, Property count: 3375
# Skipping property at Van Vollenhovenlaan 00617 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Admiraal Helfrichlaan 00619 3527KV Utrecht, Property count: 3376
# Skipping property at Admiraal Helfrichlaan 00619 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00619 3527JP Utrecht, Property count: 3377
# Skipping property at Van Vollenhovenlaan 00619 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00621 3527JP Utrecht, Property count: 3378
# Skipping property at Van Vollenhovenlaan 00621 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00623 3527JP Utrecht, Property count: 3379
# Skipping property at Van Vollenhovenlaan 00623 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00625 3527JP Utrecht, Property count: 3380
# Skipping property at Van Vollenhovenlaan 00625 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00627 3527JP Utrecht, Property count: 3381
# Skipping property at Van Vollenhovenlaan 00627 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00629 3527JP Utrecht, Property count: 3382
# Skipping property at Van Vollenhovenlaan 00629 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00631 3527JP Utrecht, Property count: 3383
# Skipping property at Van Vollenhovenlaan 00631 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00633 3527JP Utrecht, Property count: 3384
# Skipping property at Van Vollenhovenlaan 00633 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00635 3527JP Utrecht, Property count: 3385
# Skipping property at Van Vollenhovenlaan 00635 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00637 3527JP Utrecht, Property count: 3386
# Skipping property at Van Vollenhovenlaan 00637 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00639 3527JP Utrecht, Property count: 3387
# Skipping property at Van Vollenhovenlaan 00639 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00641 3527JP Utrecht, Property count: 3388
# Skipping property at Van Vollenhovenlaan 00641 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00643 3527JP Utrecht, Property count: 3389
# Skipping property at Van Vollenhovenlaan 00643 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00645 3527JP Utrecht, Property count: 3390
# Skipping property at Van Vollenhovenlaan 00645 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00647 3527JP Utrecht, Property count: 3391
# Skipping property at Van Vollenhovenlaan 00647 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00649 3527JP Utrecht, Property count: 3392
# Skipping property at Van Vollenhovenlaan 00649 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00651 3527JP Utrecht, Property count: 3393
# Skipping property at Van Vollenhovenlaan 00651 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00653 3527JP Utrecht, Property count: 3394
# Skipping property at Van Vollenhovenlaan 00653 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00655 3527JP Utrecht, Property count: 3395
# Skipping property at Van Vollenhovenlaan 00655 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00657 3527JP Utrecht, Property count: 3396
# Skipping property at Van Vollenhovenlaan 00657 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00659 3527JP Utrecht, Property count: 3397
# Skipping property at Van Vollenhovenlaan 00659 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00661 3527JP Utrecht, Property count: 3398
# Skipping property at Van Vollenhovenlaan 00661 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00663 3527JP Utrecht, Property count: 3399
# Skipping property at Van Vollenhovenlaan 00663 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00671 3527JP Utrecht, Property count: 3400
# Skipping property at Van Vollenhovenlaan 00671 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00679 3527JP Utrecht, Property count: 3401
# Skipping property at Van Vollenhovenlaan 00679 as 'gebruiksdoel' is not 'woonfunctie'
# Address being processed: Van Vollenhovenlaan 00687 3527JP Utrecht, Property count: 3402
# Skipping property at Van Vollenhovenlaan 00687 as 'gebruiksdoel' is not 'woonfunctie'
# Time taken: 1084.624572277069 seconds
# 3402
