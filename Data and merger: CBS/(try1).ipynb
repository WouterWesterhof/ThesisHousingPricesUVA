# %%
import pandas as pd
from rapidfuzz import fuzz, process  # For fuzzy matching

# %%
def initialize_csv_cbs(file_path: str):
    # Define the columns as per the specified labels
    columns = [
        "regio", "gm_naam", "recs", "gwb_code", "year", "old_name", "old_recs", "sim_score"
    ]
    # Create an empty DataFrame with these columns
    df = pd.DataFrame(columns=columns)
    # Save to CSV
    df.to_csv(file_path, index=False)
    print(f"Initialized CSV at: {file_path}")

# %%
def save_matches_to_csv(matches, file_path):
    # Create or append to a CSV file with matches
    df_matches = pd.DataFrame(matches)
    
    if not df_matches.empty:
        df_matches.to_csv(file_path, mode='a', index=False, header=False)
        print(f"Appended {len(matches)} matches to {file_path}")

# %%
def simalarity_check_gemeente(row, df_old, name_col, code_col, gm_col, typ_R, woz):
    # Fuzzy matching
    best_score = 0
    best_match = None

    for _, row_old in df_old.iterrows():
        # Check for cross-type comparisons: 'wijk' vs. 'gemeente'
        if (
            (row['recs'].lower() == 'wijk' and row_old[typ_R].lower() == 'gemeente') or
            (row['recs'].lower() == row_old[typ_R].lower())
        ):
            similarity = fuzz.ratio(row['regio'].lower(), row_old[name_col].lower())

            # Update best match if similarity is better but not perfect (100)
            if 70 <= similarity < 100 and similarity > best_score:
                best_score = similarity
                best_match = (
                    row_old[name_col],
                    row_old[gm_col],
                    row_old[typ_R],
                    row_old[woz],
                    best_score
                )

    # Log matches above the threshold
    if best_match:
        print(f"Best match for {row['regio']} ({row['gm_naam']}): {best_match[0]} ({best_match[2]}), Score: {best_score}")
        return best_match

# %%
def compare_differences(df_old, df_new, name_col, code_col, gm_col, typ_R, woz, year):
    matches = []
    second_match = []
    missing = []

    
    # Convert df_old names to lowercase for case-insensitive comparison
    df_old[name_col] = df_old[name_col].fillna("").str.lower()
    df_old[gm_col] = df_old[gm_col].fillna("").str.lower()
    df_old[typ_R] = df_old[typ_R].fillna("").str.lower()
    df_old[woz] = df_old[woz].fillna(0)  # Fill missing WOZ values with 0 or another placeholder

    df_old_set_name_R = set(zip(df_old[name_col], df_old[gm_col], df_old[typ_R], df_old[woz]))


    gm = None
    
    # Iterate through df_new rows for exact matching
    for index, row in df_new.iterrows():
        key_name_R = (row['regio'].lower(), row['gm_naam'].lower(), row['recs'].lower())

        if row['recs'].lower() == 'gemeente':

            # Search for match in old set, with check of typ_R are the same
            matched_entry = next(
                (entry for entry in df_old_set_name_R if entry[:3] == key_name_R),
                None
            )
            
            # Search for match in old set, without check of typ_R are the same
            # matched_entry = next(
            #     (entry for entry in df_old_set_name_R if entry[:2] == key_name_R[:2]),
            #     None
            # )

            
            if matched_entry:                
                matches.append({
                    "regio": row['regio'],
                    "gm_naam": row['gm_naam'],
                    "recs": row['recs'],
                    "gwb_code": row['gwb_code'],  # Assuming this is the correct mapping
                    "year": year,           
                    "gem_woz": matched_entry[3]  # Safely get 'woz' if it exists
                })
            
    
            else:
                match = simalarity_check_gemeente(row, df_old, name_col, code_col, gm_col, typ_R, woz)
                if match:
                    second_match.append({
                        "regio": row['regio'],
                        "gm_naam": row['gm_naam'],
                        "recs": row['recs'],
                        "gwb_code": row['gwb_code'], 
                        "year": year,
                        "old_name": match[0],
                        "old_recs": match[2], 
                        "sim_score": match[4]
                    })

                else: 
                    missing.append({
                        "index": index,
                        "regio": row['regio'],
                        "gm_naam": row['gm_naam'],
                    })

    
    return matches, missing, second_match

# %%
def cbs(file_path):
    
    df_24 = pd.read_excel('kwb-2024.xls', usecols=['regio', 'gm_naam', 'recs', 'gwb_code_8', 'gwb_code', 'a_inw'], dtype={'gwb_code_8': str, 'gwb_code': str, 'regio': str})
    
    for year in range(4, 5):
        year = str(year).zfill(2)  # Ensure year is two digits
        year_full = f"20{year}"
        file = f'kwb-{year_full}.xls'

        try:
            if int(year_full) < 2012:
                name = f'GWB_NAAM{year}_60pos'
                code = f'GWB_CODE{year}'
                gm = 'GM_NAAM'
                typ_R = 'RECS'
                woz = 'WOZ'

                df_cbs = pd.read_excel(file, usecols=lambda x: x.lower().strip() in [name.lower(), code.lower(), gm.lower(), woz.lower(),  typ_R.lower()])
                                
                matches, missing, second_match = compare_differences(df_cbs, df_24, name, code, gm, typ_R, woz, year_full)
                save_matches_to_csv(second_match, file_path)

                print(year_full)
                print(f"Matches found: {len(matches)}")
                print(f"Missing entries: {len(missing)}")
                print(f"Second match: {len(second_match)}")


            elif int(year_full) == 2012:
                name = f'GWB_NAAM{year}_60POS'
                code = f'GWB_CODE{year}'
                gm = 'GM_NAAM'
                typ_R = 'RECS'
                woz = 'woningwaarde'

                df_cbs = pd.read_excel(file, usecols=lambda x: x.lower().strip() in [name.lower(), f'gwb_code{year}','gm_naam', 'woz',  typ_R.lower()])
                
                matches, missing, second_match = compare_differences(df_cbs, df_24, name, code, gm, typ_R, woz, year_full)
                save_matches_to_csv(matches, file_path)

                print(year_full)
                print(f"Matches found: {len(matches)}")
                print(f"Missing entries: {len(missing)}")
                print(f"Second match: {len(second_match)}")


            elif int(year_full) > 2012:
                name = 'regio'
                code = 'gwb_code_8'
                gm = 'gm_naam'
                typ_R = 'recs'
                woz = 'g_wozbag'

                df_cbs = pd.read_excel(file, usecols=lambda x: any(sub in x.lower().strip() for sub in ['regio', 'gm_naam', 'recs', 'gwb_code_8', 'g_wozbag']))
                
                matches, missing, second_match = compare_differences(df_cbs, df_24, name, code, gm, typ_R, woz, year_full)
                save_matches_to_csv(matches, file_path)

                print(year_full)
                print(f"Matches found: {len(matches)}")
                print(f"Missing entries: {len(missing)}")
                print(f"Second match: {len(second_match)}")


                
        except Exception as e:
            print(f"Could not open {file}: {e}")
            continue

    return matches, missing, second_match

# %%
# Main script
if __name__ == "__main__":
    # Define the output file path
    file_path_2match = '/home/wouter/Documents/Scriptie/datacbs/cbs_mutations.csv'
    # Initialize the CSV file
    initialize_csv_cbs(file_path_2match)
    
    # Perform the matching process
    matches, missing, second_match = cbs(file_path_2match)
    
    # # Finalize the formatting of the CSV file
    # finalize_csv_format(file_path)
# Out:
# Initialized CSV at: /home/wouter/Documents/Scriptie/datacbs/cbs_mutations.csv
# Best match for Hengelo (O.) (Hengelo): hengelo (gld.) (gemeente), Score: 84.61538461538461
# Best match for Bergen (NH.) (Bergen (NH.)): bergen (l.) (gemeente), Score: 86.95652173913044
# Best match for Laren (NH.) (Laren): bergen (nh.) (gemeente), Score: 78.26086956521739
# Best match for Rijswijk (ZH.) (Rijswijk): rijswijk (gemeente), Score: 72.72727272727273
# Best match for Middelburg (Z.) (Middelburg): middelburg (gemeente), Score: 80.0
# Best match for Beek (L.) (Beek): bergen (l.) (gemeente), Score: 80.0
# Best match for Bergen (L.) (Bergen (L.)): bergen (nh.) (gemeente), Score: 86.95652173913044
# Best match for Koggenland (Koggenland): wester-koggenland (gemeente), Score: 74.07407407407408
# Best match for Lansingerland (Lansingerland): smallingerland (gemeente), Score: 74.07407407407408
# Best match for Berkelland (Berkelland): dinkelland (gemeente), Score: 70.0
# Best match for Dantumadiel (Dantumadiel): dantumadeel (gemeente), Score: 90.9090909090909
# Best match for Nissewaard (Nissewaard): lingewaard (gemeente), Score: 70.0
# Best match for Berg en Dal (Berg en Dal): bergen (l.) (gemeente), Score: 72.72727272727273
# Best match for Westerwolde (Westerwolde): menterwolde (gemeente), Score: 81.81818181818181
# Best match for Midden-Groningen (Midden-Groningen): groningen (gemeente), Score: 72.0
# Best match for Beekdaelen (Beekdaelen): breukelen (gemeente), Score: 73.6842105263158
# Best match for Montferland (Montferland): opsterland (gemeente), Score: 76.19047619047619
# Best match for Altena (Altena): aalten (gemeente), Score: 83.33333333333334
# Appended 18 matches to /home/wouter/Documents/Scriptie/datacbs/cbs_mutations.csv
# 2004
# Matches found: 288
# Missing entries: 36
# Second match: 18

# %%
    # # Convert df_old names to lowercase for case-insensitive comparison
    # current_df[name_col] = current_df[name_col].fillna("").str.lower()
    # current_df[gm_col] = current_df[gm_col].fillna("").str.lower()
    # current_df[code_col] = current_df[code_col].fillna("").str.lower()
    # current_df[woz] = current_df[woz].fillna(0)  # Fill missing WOZ values with 0 or another placeholder

    # #df_old_set_name_gem = set(zip(df_old[gm_col], df_old[typ_R]))
    # df_old_set_name_R = set(zip(df_old[name_col], df_old[gm_col], df_old[typ_R], df_old[woz]))

# %%
def initialize_csv_cbs(file_path: str):
    # Define the columns as per the specified labels
    columns = [
        "regio", "gm_naam", "recs", "gwb_code", "year", "gem_woz", "a_inw", "a_man", "a_vrouw", 
        "a_00_14", "a_15_24", "a_25_44", "a_45_64", "a_65_oo", "a_ongeh", "a_gehuwd", "a_gesch", "a_verwed", 
        "a_nl_all", "a_eur_al", "a_neu_al", "a_geb_nl", "a_geb_eu", "a_geb_ne", "a_gbl_eu", "a_gbl_ne", 
        "a_geb", "p_geb", "a_ste", "p_ste", "a_hh", "a_1p_hh", "a_hh_z_k", "a_hh_m_k", "g_hhgro", "bev_dich", 
        "a_woning", "p_1gezw", "p_mgezw", "p_bewndw", "p_leegsw", "p_koopw", "p_huurw", "p_wcorpw", "p_ov_hw", "p_bj_me10", "p_bj_mi10", 
        "g_ele", "g_ele_ap", "g_ele_tw", "g_ele_hw", "g_ele_2w", "g_ele_vw", "g_ele_hu", "g_ele_ko", 
        "g_gas", "g_gas_ap", "g_gas_tw", "g_gas_hw", "g_gas_2w", "g_gas_vw", "g_gas_hu", "g_gas_ko", 
        "p_stadsv", "a_opl_lg", "a_opl_md", "a_opl_hg", "p_arb_pp", "p_arb_wn", "p_arb_zs", 
        "a_inkont", "g_ink_po", "g_ink_pi", "p_ink_li", "p_ink_hi", 
        "g_hh_sti", "p_hh_li", "p_hh_hi", "p_hh_lkk", "p_hh_osm", "p_hh_110", "p_hh_120", "m_hh_ver", "a_soz_wb", "a_soz_ao", "a_soz_ww", "a_soz_ow", 
        "a_jz_tn", "p_jz_tn", "a_wmo_t", "p_wmo_t", "a_bedv", "a_bed_a", "a_bed_bf", "a_bed_gi", "a_bed_hj", "a_bed_kl", "a_bed_mn", "a_bed_oq", "a_bed_ru",
        "a_pau", "a_bst_b", "a_bst_nb", "g_pau_hh", "g_pau_km", "a_m2w", "g_afs_hp", "g_afs_gs", "g_afs_kv", "g_afs_sc", "g_3km_sc",
        "a_opp_ha", "a_lan_ha", "a_wat_ha", "pst_mvp", "pst_dekp", "ste_mvs", "ste_oad"
    ]
    # Create an empty DataFrame with these columns
    df = pd.DataFrame(columns=columns)
    # Save to CSV
    df.to_csv(file_path, index=False)
    print(f"Initialized CSV at: {file_path}")
# Out:
#   Cell In[3], line 8
#     "a_woning",", "p_1gezw", "p_mgezw", "p_bewndw", "p_leegsw", "p_koopw", "p_huurw", "p_wcorpw", "p_ov_hw", "p_bj_me10", "p_bj_mi10",
#                                                                                                                                     ^
# SyntaxError: unterminated string literal (detected at line 8)

# %%
def finalize_csv_format(file_path: str):
    """
    Finalize the CSV file by grouping rows and sorting them by gm_naam, gwb_code, and year.
    """
    try:
        # Load the CSV
        df = pd.read_csv(file_path)
        
        df["gwb_code_numeric"] = df["gwb_code"].str[2:]  # Extract characters starting from the 3rd position

        # Sort the DataFrame by gm_naam, gwb_code, and year
        df = df.sort_values(by=["gm_naam", "gwb_code_numeric", "year"], ascending=[True, True, True])
        df = df.drop(columns=["gwb_code_numeric"])

        # Save back to the same CSV fileLeeuwesteyn
        df.to_csv(file_path, index=False)
        print(f"CSV file '{file_path}' has been formatted and saved.")
    except Exception as e:
        print(f"Error during finalizing CSV: {e}")

# %%
def save_matches_to_csv(matches, file_path):
    # Create or append to a CSV file with matches
    df_matches = pd.DataFrame(matches)
    
    if not df_matches.empty:
        df_matches.to_csv(file_path, mode='a', index=False, header=False)
        print(f"Appended {len(matches)} matches to {file_path}")

# %%
#def check_with_prev_df(current_df, next_df, name_col, code_col, gm_col, typ_R, woz, wbi, year):
def check_with_prev_df(current_df, next_df, name_col, code_col, gm_col, typ_R, woz, wbi, year):

    matches = [] 
    lost_matches = []


    for _, row in next_df.iterrows():

        if pd.isna(row[wbi]):
            continue
        
        # If ind_wbi == 1, find an exact match on 'gwb_code'
        if int(row['ind_wbi']) == 1:
            matched_entry = current_df[current_df[code_col] == row[code_col]].iloc[0] if not current_df[current_df[code_col] == row[code_col]].empty else None

            if matched_entry is not None:
                matches.append({
                    "regio": row['regio'],
                    "gm_naam": row['gm_naam'],
                    "recs": row['recs'],
                    "gwb_code": row['gwb_code'],  # Assuming this is the correct mapping
                    "year": year,           
                    "gem_woz": matched_entry[woz]  # Safely get 'woz' if it exists
                })
        
        # If ind_wbi == 2, handle differently (e.g., code has changed but mapping is required)
        elif int(row['ind_wbi']) == 2:
            potential_matches = current_df[current_df['gm_naam'] == row['gm_naam']]
            print(potential_matches)
            if not potential_matches.empty:
                matched_entry = potential_matches.iloc[0]  # Take the first match for simplicity
                matches.append({
                    "regio": row['regio'],
                    "gm_naam": row['gm_naam'],
                    "recs": row['recs'],
                    "gwb_code": row['gwb_code'],  
                    "year": year,           
                    "gem_woz": matched_entry[woz] 
                })
        
           
            

    return matches

# %%
def filter_wbi(df, wbi_col):

    df[wbi_col] = pd.to_numeric(df[wbi_col], errors='coerce')
    
    # Filter the rows where 'ind_wbi' is 1, 2, or missing
    filtered_df = df[df[wbi_col].isin([1, 2]) | df[wbi_col].isna()]
    
    return filtered_df

# %%
def wbi_load(file_path):
    matches = []  # Initialize the matches list at the start

    incl_feat =  []
    
    df_next_year = None  # Initialize the DataFrame for the next year
    df_24 = None  # For storing data specifically for 2024
    
    for year in range(24, 22, -1):  # Adjust range as needed for other years
        year = str(year).zfill(2)  # Ensure year is two digits
        year_full = f"20{year}"
        file = f'kwb-{year_full}.xls'

        try:
            if int(year_full) > 2012:
                name_col = 'regio'
                code_col = 'gwb_code'
                gm_col = 'gm_naam'
                typ_R = 'recs'
                wbi = 'ind_wbi'
                
                if int(year_full) <= 2019:
                    woz = 'g_woz'
                
                else:
                    woz = 'g_wozbag'
               
                df_cur_year = pd.read_excel(
                    file, 
                    usecols=lambda x: any(sub in x.lower().strip() for sub in ['regio', 'gm_naam', 'recs', 'gwb_code', woz, 'ind_wbi']),
                    dtype={'gwb_code': str, 'regio': str}
                )
                
                df_cur_year_filt = filter_wbi(df_cur_year, wbi)
                
                if int(year_full) == 2024:
                    df_24 = df_cur_year_filt
                    
                
                else:
                    print(f'Processing year: {year_full}')
                    year_matches = check_with_prev_df(
                        df_cur_year, 
                        df_next_year, 
                        name_col, 
                        code_col, 
                        gm_col, 
                        typ_R, 
                        woz, 
                        wbi, 
                        year_full
                    )
                    
                    matches.extend(year_matches)  # Append to the overall matches list
                    save_matches_to_csv(year_matches, file_path)

                df_next_year = df_cur_year_filt
                #print(df_next_year)

        except Exception as e:
            print(f"Could not open {file}: {e}")
            continue
    
    return matches

# %%
# Main script
if __name__ == "__main__":
    file_path = '/home/wouter/Documents/Scriptie/datacbs/cbs_final.csv'
    
    initialize_csv_cbs(file_path)
    matches = wbi_load(file_path)
    
    # Finalize the formatting of the CSV file
    finalize_csv_format(file_path)
# Out:
# Initialized CSV at: /home/wouter/Documents/Scriptie/datacbs/cbs_final.csv
# Processing year: 2023
# Appended 17351 matches to /home/wouter/Documents/Scriptie/datacbs/cbs_final.csv
# Processing year: 2022
# Appended 17422 matches to /home/wouter/Documents/Scriptie/datacbs/cbs_final.csv
# Processing year: 2021
# Appended 16851 matches to /home/wouter/Documents/Scriptie/datacbs/cbs_final.csv
# Processing year: 2020
# Appended 16001 matches to /home/wouter/Documents/Scriptie/datacbs/cbs_final.csv
# Processing year: 2019
# Appended 16196 matches to /home/wouter/Documents/Scriptie/datacbs/cbs_final.csv
# Processing year: 2018
# Appended 14955 matches to /home/wouter/Documents/Scriptie/datacbs/cbs_final.csv
# Processing year: 2017
# Appended 15368 matches to /home/wouter/Documents/Scriptie/datacbs/cbs_final.csv
# Processing year: 2016
# Appended 15137 matches to /home/wouter/Documents/Scriptie/datacbs/cbs_final.csv
# Processing year: 2015
# Appended 14018 matches to /home/wouter/Documents/Scriptie/datacbs/cbs_final.csv
# Processing year: 2014
# Appended 13821 matches to /home/wouter/Documents/Scriptie/datacbs/cbs_final.csv
# Processing year: 2013
# Appended 13838 matches to /home/wouter/Documents/Scriptie/datacbs/cbs_final.csv
# CSV file '/home/wouter/Documents/Scriptie/datacbs/cbs_final.csv' has been formatted and saved.

# %%
import pandas as pd

def count_wbi_3(df, year, wbi_column, regio_column, woz_column):
    """
    Counts rows where `wbi_column` equals 3 and collects `regio` and `woz` for those rows.
    
    Args:
        df (pd.DataFrame): The DataFrame for the current year.
        year (str): The year of the data being processed.
        wbi_column (str): The column representing the WBI indicator.
        regio_column (str): The column representing the region name.
        woz_column (str): The column representing the WOZ value.
    
    Returns:
        list: A list of dictionaries containing year, regio, and woz for rows where wbi == 3.
    """
    wbi_3_list = []
    filtered_df = df[df[wbi_column] == 3]
    
    for _, row in filtered_df.iterrows():
        wbi_3_list.append({
            'year': year,
            'regio': row[regio_column],
            'woz': row[woz_column]
        })
    
    return wbi_3_list

# %%
def wbi_check_on_3():

    wbi_3_over_years = []
    
    df_next_year = None  # Initialize the DataFrame for the next year
    df_24 = None  # For storing data specifically for 2024
    
    for year in range(24, 22, -1):  # Adjust range as needed for other years
        year = str(year).zfill(2)  # Ensure year is two digits
        year_full = f"20{year}"
        file = f'kwb-{year_full}.xls'

        try:
            if int(year_full) > 2012:
                name_col = 'regio'
                code_col = 'gwb_code'
                gm_col = 'gm_naam'
                typ_R = 'recs'
                wbi = 'ind_wbi'
                
                if int(year_full) <= 2019:
                    woz = 'g_woz'
                
                else:
                    woz = 'g_wozbag'
               
                df_cur_year = pd.read_excel(
                    file, 
                    usecols=lambda x: any(sub in x.lower().strip() for sub in ['regio', 'gm_naam', 'recs', 'gwb_code', woz, 'ind_wbi']),
                    dtype={'gwb_code': str, 'regio': str}
                )
                
                
                # if int(year_full) == 2024:
                #     df_24 = df_cur_year
                    
                print(f'Processing year: {year_full}')
                wbi_3_data = count_wbi_3(df_cur_year, year_full, wbi, name_col, woz)
                wbi_3_over_years.extend(wbi_3_data)
                
        except Exception as e:
            print(f"Could not open {file}: {e}")
            continue
    
    return wbi_3_over_years

# %%
if __name__ == "__main__":
  
    list3 = wbi_check_on_3()
    print(list3)
# Out:
# Processing year: 2024
# Processing year: 2023
# [{'year': '2024', 'regio': 'Dokkumer Ie e.o.', 'woz': '.'}, {'year': '2024', 'regio': 'Jelsum', 'woz': '.'}, {'year': '2024', 'regio': 'Buitengebied Jelsum', 'woz': '.'}, {'year': '2024', 'regio': 'Koarnjum', 'woz': '.'}, {'year': '2024', 'regio': 'Buitengebied Koarnjum', 'woz': '.'}, {'year': '2024', 'regio': 'Britsum', 'woz': '.'}, {'year': '2024', 'regio': 'Buitengebied Britsum', 'woz': '.'}, {'year': '2024', 'regio': 'Stiens e.o.', 'woz': '.'}, {'year': '2024', 'regio': 'Stiens', 'woz': '.'}, {'year': '2024', 'regio': 'Buitengebied Stiens', 'woz': '.'}, {'year': '2024', 'regio': 'Buitengebied Hempens', 'woz': '.'}, {'year': '2024', 'regio': 'Zuiderburen', 'woz': '.'}, {'year': '2024', 'regio': 'Middelsee', 'woz': '.'}, {'year': '2024', 'regio': 'Swichum', 'woz': '.'}, {'year': '2024', 'regio': 'Buitengebied Wirdum', 'woz': '.'}, {'year': '2024', 'regio': 'Mantgum', 'woz': '.'}, {'year': '2024', 'regio': 'Buitengebied Mantgum', 'woz': '.'}, {'year': '2024', 'regio': 'Weidum', 'woz': '.'}, {'year': '2024', 'regio': 'Buitengebied Weidum', 'woz': '.'}, {'year': '2024', 'regio': 'Jorwert', 'woz': '.'}, {'year': '2024', 'regio': 'Buitengebied Jorwert', 'woz': '.'}, {'year': '2024', 'regio': 'Hilaard', 'woz': '.'}, {'year': '2024', 'regio': 'Buitengebied Hilaard', 'woz': '.'}, {'year': '2024', 'regio': 'Easterlittens', 'woz': '.'}, {'year': '2024', 'regio': 'Buitengebied Easterlittens', 'woz': '.'}, {'year': '2024', 'regio': 'Friens', 'woz': '.'}, {'year': '2024', 'regio': 'Jirnsum', 'woz': '.'}, {'year': '2024', 'regio': 'Centrum', 'woz': '.'}, {'year': '2024', 'regio': 'Drachten centrum', 'woz': '.'}, {'year': '2024', 'regio': 'De Wiken', 'woz': '.'}, {'year': '2024', 'regio': 'De Wiken noord', 'woz': '.'}, {'year': '2024', 'regio': 'De Wiken west', 'woz': '.'}, {'year': '2024', 'regio': 'De Wiken noordoost', 'woz': '.'}, {'year': '2024', 'regio': 'De Wiken centrum', 'woz': '.'}, {'year': '2024', 'regio': 'De Wiken zuid', 'woz': '.'}, {'year': '2024', 'regio': 'De Wiken oost', 'woz': '.'}, {'year': '2024', 'regio': 'De Singels', 'woz': '.'}, {'year': '2024', 'regio': 'De Peppel', 'woz': '.'}, {'year': '2024', 'regio': 'De Singels west', 'woz': '.'}, {'year': '2024', 'regio': 'De Singels oost', 'woz': '.'}, {'year': '2024', 'regio': 'De Singels zuid', 'woz': '.'}, {'year': '2024', 'regio': 'De Drait', 'woz': '.'}, {'year': '2024', 'regio': 'De Drait Zuid', 'woz': '.'}, {'year': '2024', 'regio': 'De Drait west', 'woz': '.'}, {'year': '2024', 'regio': 'De Drait noordoost', 'woz': '.'}, {'year': '2024', 'regio': 'De Drait zuidoost', 'woz': '.'}, {'year': '2024', 'regio': 'De Drait noordwest', 'woz': '.'}, {'year': '2024', 'regio': 'De Drait zuidwest', 'woz': '.'}, {'year': '2024', 'regio': 'Drachtstervaart', 'woz': '.'}, {'year': '2024', 'regio': 'Drachstervaart west', 'woz': '.'}, {'year': '2024', 'regio': 'Drachstervaart oost', 'woz': '.'}, {'year': '2024', 'regio': 'De Venen', 'woz': '.'}, {'year': '2024', 'regio': 'De Venen noord', 'woz': '.'}, {'year': '2024', 'regio': 'De Venen centrum', 'woz': '.'}, {'year': '2024', 'regio': 'De Venen zuid', 'woz': '.'}, {'year': '2024', 'regio': 'De Folgeren', 'woz': '.'}, {'year': '2024', 'regio': 'De Folgeren zuidwest', 'woz': '.'}, {'year': '2024', 'regio': 'De Folgeren noord', 'woz': '.'}, {'year': '2024', 'regio': 'De Folgeren centrum', 'woz': '.'}, {'year': '2024', 'regio': 'Fennepark', 'woz': '.'}, {'year': '2024', 'regio': 'Burmaniapark', 'woz': '.'}, {'year': '2024', 'regio': 'Vrijburgh', 'woz': '.'}, {'year': '2024', 'regio': 'De Swetten', 'woz': '.'}, {'year': '2024', 'regio': 'De Swetten west', 'woz': '.'}, {'year': '2024', 'regio': 'De Swetten centrum', 'woz': '.'}, {'year': '2024', 'regio': 'De Swetten oost', 'woz': '.'}, {'year': '2024', 'regio': 'De Bouwen', 'woz': '.'}, {'year': '2024', 'regio': 'De Bouwen noord', 'woz': '.'}, {'year': '2024', 'regio': 'De Bouwen west', 'woz': '.'}, {'year': '2024', 'regio': 'De Bouwen oost', 'woz': '.'}, {'year': '2024', 'regio': 'De Bouwe ...

# %%
for row in list3:
    print(row)
# Out:
# {'year': '2024', 'regio': 'Dokkumer Ie e.o.', 'woz': '.'}
# {'year': '2024', 'regio': 'Jelsum', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Jelsum', 'woz': '.'}
# {'year': '2024', 'regio': 'Koarnjum', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Koarnjum', 'woz': '.'}
# {'year': '2024', 'regio': 'Britsum', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Britsum', 'woz': '.'}
# {'year': '2024', 'regio': 'Stiens e.o.', 'woz': '.'}
# {'year': '2024', 'regio': 'Stiens', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Stiens', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Hempens', 'woz': '.'}
# {'year': '2024', 'regio': 'Zuiderburen', 'woz': '.'}
# {'year': '2024', 'regio': 'Middelsee', 'woz': '.'}
# {'year': '2024', 'regio': 'Swichum', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Wirdum', 'woz': '.'}
# {'year': '2024', 'regio': 'Mantgum', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Mantgum', 'woz': '.'}
# {'year': '2024', 'regio': 'Weidum', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Weidum', 'woz': '.'}
# {'year': '2024', 'regio': 'Jorwert', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Jorwert', 'woz': '.'}
# {'year': '2024', 'regio': 'Hilaard', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Hilaard', 'woz': '.'}
# {'year': '2024', 'regio': 'Easterlittens', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Easterlittens', 'woz': '.'}
# {'year': '2024', 'regio': 'Friens', 'woz': '.'}
# {'year': '2024', 'regio': 'Jirnsum', 'woz': '.'}
# {'year': '2024', 'regio': 'Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Drachten centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'De Wiken', 'woz': '.'}
# {'year': '2024', 'regio': 'De Wiken noord', 'woz': '.'}
# {'year': '2024', 'regio': 'De Wiken west', 'woz': '.'}
# {'year': '2024', 'regio': 'De Wiken noordoost', 'woz': '.'}
# {'year': '2024', 'regio': 'De Wiken centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'De Wiken zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'De Wiken oost', 'woz': '.'}
# {'year': '2024', 'regio': 'De Singels', 'woz': '.'}
# {'year': '2024', 'regio': 'De Peppel', 'woz': '.'}
# {'year': '2024', 'regio': 'De Singels west', 'woz': '.'}
# {'year': '2024', 'regio': 'De Singels oost', 'woz': '.'}
# {'year': '2024', 'regio': 'De Singels zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'De Drait', 'woz': '.'}
# {'year': '2024', 'regio': 'De Drait Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'De Drait west', 'woz': '.'}
# {'year': '2024', 'regio': 'De Drait noordoost', 'woz': '.'}
# {'year': '2024', 'regio': 'De Drait zuidoost', 'woz': '.'}
# {'year': '2024', 'regio': 'De Drait noordwest', 'woz': '.'}
# {'year': '2024', 'regio': 'De Drait zuidwest', 'woz': '.'}
# {'year': '2024', 'regio': 'Drachtstervaart', 'woz': '.'}
# {'year': '2024', 'regio': 'Drachstervaart west', 'woz': '.'}
# {'year': '2024', 'regio': 'Drachstervaart oost', 'woz': '.'}
# {'year': '2024', 'regio': 'De Venen', 'woz': '.'}
# {'year': '2024', 'regio': 'De Venen noord', 'woz': '.'}
# {'year': '2024', 'regio': 'De Venen centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'De Venen zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'De Folgeren', 'woz': '.'}
# {'year': '2024', 'regio': 'De Folgeren zuidwest', 'woz': '.'}
# {'year': '2024', 'regio': 'De Folgeren noord', 'woz': '.'}
# {'year': '2024', 'regio': 'De Folgeren centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Fennepark', 'woz': '.'}
# {'year': '2024', 'regio': 'Burmaniapark', 'woz': '.'}
# {'year': '2024', 'regio': 'Vrijburgh', 'woz': '.'}
# {'year': '2024', 'regio': 'De Swetten', 'woz': '.'}
# {'year': '2024', 'regio': 'De Swetten west', 'woz': '.'}
# {'year': '2024', 'regio': 'De Swetten centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'De Swetten oost', 'woz': '.'}
# {'year': '2024', 'regio': 'De Bouwen', 'woz': '.'}
# {'year': '2024', 'regio': 'De Bouwen noord', 'woz': '.'}
# {'year': '2024', 'regio': 'De Bouwen west', 'woz': '.'}
# {'year': '2024', 'regio': 'De Bouwen oost', 'woz': '.'}
# {'year': '2024', 'regio': 'De Bouwen zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Noord-Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Noord-Oost noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Noord-Oost west', 'woz': '.'}
# {'year': '2024', 'regio': 'Noord-Oost zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Noord-Oost oost', 'woz': '.'}
# {'year': '2024', 'regio': 'De Haven', 'woz': '.'}
# {'year': '2024', 'regio': 'De Haven', 'woz': '.'}
# {'year': '2024', 'regio': 'Drachten Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'A7 Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Waldwei oost', 'woz': '.'}
# {'year': '2024', 'regio': 'De Trisken', 'woz': '.'}
# {'year': '2024', 'regio': 'De Trisken centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'De Trisken rondom', 'woz': '.'}
# {'year': '2024', 'regio': 'Himsterhout', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Opeinde, onder de Vaart', 'woz': '.'}
# {'year': '2024', 'regio': 'Opeinde, boven de Vaart', 'woz': '.'}
# {'year': '2024', 'regio': 'Nijega', 'woz': '.'}
# {'year': '2024', 'regio': 'Oudega', 'woz': '.'}
# {'year': '2024', 'regio': 'De Tike', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied West', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied west', 'woz': '.'}
# {'year': '2024', 'regio': 'De Wilgen', 'woz': '.'}
# {'year': '2024', 'regio': 'De Wilgen, Sanding', 'woz': '.'}
# {'year': '2024', 'regio': 'Boornbergum', 'woz': '.'}
# {'year': '2024', 'regio': 'Smalle Ee', 'woz': '.'}
# {'year': '2024', 'regio': 'Goengahuizen', 'woz': '.'}
# {'year': '2024', 'regio': 'De Veenhoop', 'woz': '.'}
# {'year': '2024', 'regio': 'Kortehemmen', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Drachtstercompagnie', 'woz': '.'}
# {'year': '2024', 'regio': 'Houtigehage', 'woz': '.'}
# {'year': '2024', 'regio': 'Rottevalle', 'woz': '.'}
# {'year': '2024', 'regio': 'Ane', 'woz': '.'}
# {'year': '2024', 'regio': 'Ane Dorp', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Ane', 'woz': '.'}
# {'year': '2024', 'regio': 'Anerveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Anerveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Anevelde', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Anevelde', 'woz': '.'}
# {'year': '2024', 'regio': 'Balkbrug', 'woz': '.'}
# {'year': '2024', 'regio': 'Balkbrug-Zuidwest', 'woz': '.'}
# {'year': '2024', 'regio': 'Balkbrug-Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Balkbrug-Zuidoost', 'woz': '.'}
# {'year': '2024', 'regio': 'Balkbrug-Benedenvaart', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen De Kolonie', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Reestgebied (ged.)', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Westerhuizingerveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Bergentheim', 'woz': '.'}
# {'year': '2024', 'regio': 'Bergentheim Kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Bergentheimerveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Oud-Bergentheim', 'woz': '.'}
# {'year': '2024', 'regio': 'Brucht', 'woz': '.'}
# {'year': '2024', 'regio': 'Brucht', 'woz': '.'}
# {'year': '2024', 'regio': 'Collendoorn', 'woz': '.'}
# {'year': '2024', 'regio': 'Collendoorn', 'woz': '.'}
# {'year': '2024', 'regio': 'De Krim', 'woz': '.'}
# {'year': '2024', 'regio': 'De Krim', 'woz': '.'}
# {'year': '2024', 'regio': 'De Krim-Streekdorp', 'woz': '.'}
# {'year': '2024', 'regio': 'De Krim-Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen De Krim', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Nieuwlande', 'woz': '.'}
# {'year': '2024', 'regio': 'Dedemsvaart', 'woz': '.'}
# {'year': '2024', 'regio': 'Dedemsvaart-Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Dedemsvaart-Zuidwest', 'woz': '.'}
# {'year': '2024', 'regio': 'Dedemsvaart-Zuidoost', 'woz': '.'}
# {'year': '2024', 'regio': 'Rheezerend', 'woz': '.'}
# {'year': '2024', 'regio': 'Industriegebied Rollepaal', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Colenbranderbos', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Dedemsvaart', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Ommerkanaal', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Reestgebied', 'woz': '.'}
# {'year': '2024', 'regio': 'Den Velde', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Den Velde', 'woz': '.'}
# {'year': '2024', 'regio': 'Diffelen', 'woz': '.'}
# {'year': '2024', 'regio': 'Diffelen', 'woz': '.'}
# {'year': '2024', 'regio': 'Gramsbergen', 'woz': '.'}
# {'year': '2024', 'regio': 'Gramsbergen Kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Gramsbergen Uitbreidingsplan', 'woz': '.'}
# {'year': '2024', 'regio': 'Heemserveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Heemserveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Holtheme', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Holtheme-De Haandrik', 'woz': '.'}
# {'year': '2024', 'regio': 'Holthone', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Holthone', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoogenweg', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoogenweg', 'woz': '.'}
# {'year': '2024', 'regio': 'Kloosterhaar', 'woz': '.'}
# {'year': '2024', 'regio': 'Kloosterhaar Kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Kloosterhaar', 'woz': '.'}
# {'year': '2024', 'regio': 'Loozen', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Loozen', 'woz': '.'}
# {'year': '2024', 'regio': 'Lutten', 'woz': '.'}
# {'year': '2024', 'regio': 'Lutten Kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Lutten-West', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Lutten-Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Oud-Lutten', 'woz': '.'}
# {'year': '2024', 'regio': 'Marienberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Marienberg Kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Marienberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Radewijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Radewijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Rheeze', 'woz': '.'}
# {'year': '2024', 'regio': 'Rheeze', 'woz': '.'}
# {'year': '2024', 'regio': 'Rheezerveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Rheezerveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Schuinesloot', 'woz': '.'}
# {'year': '2024', 'regio': 'Schuinesloot Kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Schuinesloot', 'woz': '.'}
# {'year': '2024', 'regio': 'Sibculo', 'woz': '.'}
# {'year': '2024', 'regio': 'Sibculo Kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Sibculo', 'woz': '.'}
# {'year': '2024', 'regio': 'Slagharen', 'woz': '.'}
# {'year': '2024', 'regio': 'Slagharen Kern', 'woz': '.'}
# {'year': '2024', 'regio': 'De Belt', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Slagharen-Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Slagharen-West', 'woz': '.'}
# {'year': '2024', 'regio': 'Venebrugge', 'woz': '.'}
# {'year': '2024', 'regio': 'Venebrugge', 'woz': '.'}
# {'year': '2024', 'regio': 'Hardenberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Overig Stad Hardenberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Industriegebied', 'woz': '.'}
# {'year': '2024', 'regio': 'Norden en Hazenbos', 'woz': '.'}
# {'year': '2024', 'regio': 'Heemse-Oost Heemsermars', 'woz': '.'}
# {'year': '2024', 'regio': 'Heemse-West Heemserbos', 'woz': '.'}
# {'year': '2024', 'regio': 'Baalder', 'woz': '.'}
# {'year': '2024', 'regio': 'Baalderveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Marslanden', 'woz': '.'}
# {'year': '2024', 'regio': 'Centrum Saneringsgebied', 'woz': '.'}
# {'year': '2024', 'regio': 'De Velden', 'woz': '.'}
# {'year': '2024', 'regio': 'Havezate Es', 'woz': '.'}
# {'year': '2024', 'regio': 'Leehoogte', 'woz': '.'}
# {'year': '2024', 'regio': 'Ydenhoogte', 'woz': '.'}
# {'year': '2024', 'regio': 'Bruchterveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Bruchterveld Kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Bruchterveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Ommen', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Ommeres', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Laarakkers', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Ommen ten zuiden van de Vecht', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Industrieterrein', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Junne', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Eerde', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Besthmen', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Varsen', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Ommerbos-Ommerkanaal', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Emsland', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Zeesse', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Zuid - ten noorden v spoor', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Zuid - ten zuiden v spoor', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Dante noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Dante zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Zeeheldenbuurt - Lodderholt', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Strangen', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Alteveer Wonen 5-6', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Rotbrink', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Alteveer wonen 1-4', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Alteveer Bedrijven', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Alteveer Voorzieningen', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Havengebied', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - Vlierlanden', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ommen - sportpark Westbroek', 'woz': '.'}
# {'year': '2024', 'regio': 'Arrien', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Arrien', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Arrienveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Beerze', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Beerze', 'woz': '.'}
# {'year': '2024', 'regio': 'Beerzerveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Beerzerveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Kloosterdijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Beerzerveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Dalmsholte', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Dalmsholte', 'woz': '.'}
# {'year': '2024', 'regio': 'Giethmen', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Giethmen', 'woz': '.'}
# {'year': '2024', 'regio': 'Lemele', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Lemele', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Lemele', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Archem', 'woz': '.'}
# {'year': '2024', 'regio': 'Stegeren', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Stegeren', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Stegerveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Vilsteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Vilsteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Vilsteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Vinkenbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Vinkenbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Ommerschans', 'woz': '.'}
# {'year': '2024', 'regio': 'Witharen', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Witharen', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Witharen', 'woz': '.'}
# {'year': '2024', 'regio': 'Buurtschap Ommerveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Het Raan Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Raalte', 'woz': '.'}
# {'year': '2024', 'regio': 'Mariënheem Kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Mariënheem', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuw Heeten Kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Nieuw Heeten', 'woz': '.'}
# {'year': '2024', 'regio': 'Heeten Kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Heeten', 'woz': '.'}
# {'year': '2024', 'regio': 'Heino Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Blankenfoort', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Heino', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk 00 Tubbergen', 'woz': '.'}
# {'year': '2024', 'regio': 'Tubbergen noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Tubbergen west', 'woz': '.'}
# {'year': '2024', 'regio': 'Tubbergen oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Tubbergen', 'woz': '.'}
# {'year': '2024', 'regio': 'Tubbergen industrie Boskamp', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk 01 Albergen', 'woz': '.'}
# {'year': '2024', 'regio': 'Albergen noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Albergen zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Albergen', 'woz': '.'}
# {'year': '2024', 'regio': 'Albergen industrie', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk 02 Harbrinkhoek', 'woz': '.'}
# {'year': '2024', 'regio': 'Harbrinkhoek kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Harbrinkhoek', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk 03 Geesteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Geesteren noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Geesteren zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Geesteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Geesteren industrie Lutkeberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk 04 Langeveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Langeveen kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Langeveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk 05 Vasse', 'woz': '.'}
# {'year': '2024', 'regio': 'Vasse kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Vasse', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk 06 Reutum', 'woz': '.'}
# {'year': '2024', 'regio': 'Reutum kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Reutum', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk 07 Fleringen', 'woz': '.'}
# {'year': '2024', 'regio': 'Fleringen kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Fleringen', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk Mariaparochie', 'woz': '.'}
# {'year': '2024', 'regio': 'Mariaparochie', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk Manderveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Manderveen kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Manderveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk Mander', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Mander', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk Hezingen', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Hezingen', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk Haarle', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Haarle', 'woz': '.'}
# {'year': '2024', 'regio': 'Druten Buitengebied', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Druten', 'woz': '.'}
# {'year': '2024', 'regio': 'Druten', 'woz': '.'}
# {'year': '2024', 'regio': 'Boldershof', 'woz': '.'}
# {'year': '2024', 'regio': 'Delenoord', 'woz': '.'}
# {'year': '2024', 'regio': 'Druten West', 'woz': '.'}
# {'year': '2024', 'regio': 'Oud Druten', 'woz': '.'}
# {'year': '2024', 'regio': 'Druten Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Oranjebuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Zeevaarders', 'woz': '.'}
# {'year': '2024', 'regio': 'Tichellande', 'woz': '.'}
# {'year': '2024', 'regio': 'Bedrijventerrein Kerkeland', 'woz': '.'}
# {'year': '2024', 'regio': 'Druten Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'De Koekoek', 'woz': '.'}
# {'year': '2024', 'regio': 'Klein Middelveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitenhof', 'woz': '.'}
# {'year': '2024', 'regio': 'Bouwing', 'woz': '.'}
# {'year': '2024', 'regio': 'Bedrijventerrein Klepperheide', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Deest', 'woz': '.'}
# {'year': '2024', 'regio': 'Deest', 'woz': '.'}
# {'year': '2024', 'regio': 'Bedrijventerrein Deest', 'woz': '.'}
# {'year': '2024', 'regio': 'Afferden', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Afferden', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Puiflijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Puiflijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Horssen', 'woz': '.'}
# {'year': '2024', 'regio': 'Horssen', 'woz': '.'}
# {'year': '2024', 'regio': 'Molenhoek', 'woz': '.'}
# {'year': '2024', 'regio': 'De Wereldsteden', 'woz': '.'}
# {'year': '2024', 'regio': 'Het Groene Balkon', 'woz': '.'}
# {'year': '2024', 'regio': 'Jutphaas Wijkersloot', 'woz': '.'}
# {'year': '2024', 'regio': 'Jutphaas', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijkersloot-Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijkersloot-West', 'woz': '.'}
# {'year': '2024', 'regio': 'Zuilenstein', 'woz': '.'}
# {'year': '2024', 'regio': 'Zuilenstein-Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Zuilenstein-Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Batau Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Driften-Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Gaarden', 'woz': '.'}
# {'year': '2024', 'regio': 'Batau Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Burgen', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitenweides', 'woz': '.'}
# {'year': '2024', 'regio': 'Doorslag', 'woz': '.'}
# {'year': '2024', 'regio': 'Doorslag-Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Doorslag-Zuidwest', 'woz': '.'}
# {'year': '2024', 'regio': 'Huis de Geer', 'woz': '.'}
# {'year': '2024', 'regio': 'Huis de Geer', 'woz': '.'}
# {'year': '2024', 'regio': 'Blokhoeve', 'woz': '.'}
# {'year': '2024', 'regio': 'Blokhoeve', 'woz': '.'}
# {'year': '2024', 'regio': 'Galecop', 'woz': '.'}
# {'year': '2024', 'regio': 'Hagen', 'woz': '.'}
# {'year': '2024', 'regio': 'Galecopperzoom', 'woz': '.'}
# {'year': '2024', 'regio': 'Fokkesteeg', 'woz': '.'}
# {'year': '2024', 'regio': 'Vesten', 'woz': '.'}
# {'year': '2024', 'regio': 'Schansen', 'woz': '.'}
# {'year': '2024', 'regio': 'Graven en Gravinnen', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoogzandveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoogzandveld-Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoogzandveld-West', 'woz': '.'}
# {'year': '2024', 'regio': 'Lekboulevard', 'woz': '.'}
# {'year': '2024', 'regio': 'Lekboulevard', 'woz': '.'}
# {'year': '2024', 'regio': 'Vreeswijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Vreeswijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuw Vreeswijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Merwestein', 'woz': '.'}
# {'year': '2024', 'regio': 'Merwestein', 'woz': '.'}
# {'year': '2024', 'regio': 'Park Oudegein', 'woz': '.'}
# {'year': '2024', 'regio': 'Park Oudegein', 'woz': '.'}
# {'year': '2024', 'regio': 'Zandveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Zandveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Het Klooster', 'woz': '.'}
# {'year': '2024', 'regio': 'Het Klooster', 'woz': '.'}
# {'year': '2024', 'regio': 'Laagraven', 'woz': '.'}
# {'year': '2024', 'regio': 'De Liesbosch', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Laagraven', 'woz': '.'}
# {'year': '2024', 'regio': 'Plettenburg', 'woz': '.'}
# {'year': '2024', 'regio': 'Plettenburg', 'woz': '.'}
# {'year': '2024', 'regio': 'De Wiers', 'woz': '.'}
# {'year': '2024', 'regio': 'De Wiers', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoge Landen', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoge Landen', 'woz': '.'}
# {'year': '2024', 'regio': 'Stadscentrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Stadscentrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Rijnhuizen', 'woz': '.'}
# {'year': '2024', 'regio': 'Rijnhuizen', 'woz': '.'}
# {'year': '2024', 'regio': 'Driemond', 'woz': '.'}
# {'year': '2024', 'regio': 'Landelijk gebied Driemond', 'woz': '.'}
# {'year': '2024', 'regio': 'Dorp Driemond', 'woz': '.'}
# {'year': '2024', 'regio': 'Nellestein', 'woz': '.'}
# {'year': '2024', 'regio': 'Gaasperpark', 'woz': '.'}
# {'year': '2024', 'regio': 'Gaasperplas', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoofddorp', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoofddorp Centrum Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoofddorp Hyde Park', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoofddorp Floriande Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuw-Vennep', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuw-Vennep Omgeving', 'woz': '.'}
# {'year': '2024', 'regio': 'Lijnden Omgeving', 'woz': '.'}
# {'year': '2024', 'regio': 'Lijnden', 'woz': '.'}
# {'year': '2024', 'regio': 'Debbemeer-Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Warmenhuizen', 'woz': '.'}
# {'year': '2024', 'regio': 'Kalverdijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Tuitjenhorn', 'woz': '.'}
# {'year': '2024', 'regio': 'Waarland (woonkern)', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Waarland', 'woz': '.'}
# {'year': '2024', 'regio': 'Zaandam Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Vijfhoekpark', 'woz': '.'}
# {'year': '2024', 'regio': 'Achtersluispolder', 'woz': '.'}
# {'year': '2024', 'regio': 'Bomenbuurt Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Bomenbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Burgemeestersbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Prins Hendrikbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Poelenburg', 'woz': '.'}
# {'year': '2024', 'regio': 'Vennenbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Poelenburg Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Poelenburg Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Pelders- en Hoornseveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Peldersveld West', 'woz': '.'}
# {'year': '2024', 'regio': 'Peldersveld Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoornseveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Kleurenbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Rosmolenwijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Rosmolenbuurt Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Rosmolenbuurt West', 'woz': '.'}
# {'year': '2024', 'regio': 'Kogerveldwijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Oostzijderveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Kogerveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Boerejonkerbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Hofwijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Kalf Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Kalf', 'woz': '.'}
# {'year': '2024', 'regio': 'Zaanse Schans', 'woz': '.'}
# {'year': '2024', 'regio': 'Oude Haven', 'woz': '.'}
# {'year': '2024', 'regio': 'Havenbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Hembrugterrein', 'woz': '.'}
# {'year': '2024', 'regio': 'Zuiderhout Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Zuiderhout', 'woz': '.'}
# {'year': '2024', 'regio': 'Het Eiland', 'woz': '.'}
# {'year': '2024', 'regio': 'Russische buurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Zaandam West', 'woz': '.'}
# {'year': '2024', 'regio': 'Oud West', 'woz': '.'}
# {'year': '2024', 'regio': 'Spoorbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Schilders- en Waddenbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuw West', 'woz': '.'}
# {'year': '2024', 'regio': 'Westerspoor', 'woz': '.'}
# {'year': '2024', 'regio': 'Westzanerdijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Westzijderveld Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Zaans Hout', 'woz': '.'}
# {'year': '2024', 'regio': 'Westzijderveld Midden', 'woz': '.'}
# {'year': '2024', 'regio': 'Westerwatering Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Westerwatering Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Oud Koog a/d Zaan', 'woz': '.'}
# {'year': '2024', 'regio': 'Oud Koog', 'woz': '.'}
# {'year': '2024', 'regio': 'Westerkoog', 'woz': '.'}
# {'year': '2024', 'regio': 'Westzijderveld Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Westerkoog Midden', 'woz': '.'}
# {'year': '2024', 'regio': 'Westerkoog Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Oud Zaandijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Oud Zaandijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Rooswijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Rooswijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Rooswijk Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Guisveld Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Wormerveer', 'woz': '.'}
# {'year': '2024', 'regio': 'Wormerveer Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Guisveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Wormerveer Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Wormerveer Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Wormerveer West', 'woz': '.'}
# {'year': '2024', 'regio': 'Karnemelksepolder', 'woz': '.'}
# {'year': '2024', 'regio': 'Westknollendam', 'woz': '.'}
# {'year': '2024', 'regio': 'Industriebuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Krommenie Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Zuiderhoofdbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Noorderhoofdbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Snuiverbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Rosariumbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Krommenie West', 'woz': '.'}
# {'year': '2024', 'regio': 'Zuiderham', 'woz': '.'}
# {'year': '2024', 'regio': 'Noorderham', 'woz': '.'}
# {'year': '2024', 'regio': 'Krommeniedijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Willis', 'woz': '.'}
# {'year': '2024', 'regio': 'Assendelft-Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'De Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Westerpolder', 'woz': '.'}
# {'year': '2024', 'regio': 'Assendelft-Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Noorderveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Waterrijk West', 'woz': '.'}
# {'year': '2024', 'regio': 'Waterrijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Langeheit Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Langeheit West', 'woz': '.'}
# {'year': '2024', 'regio': 'De Omzoom', 'woz': '.'}
# {'year': '2024', 'regio': 'Kreekrijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Parkrijk Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Parkrijk Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Westzaan', 'woz': '.'}
# {'year': '2024', 'regio': 'Westzanerpolder', 'woz': '.'}
# {'year': '2024', 'regio': 'Westzaan Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'J.J. Allanbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Westzaan Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Middel', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Nieuwkoop', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuwkoop', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuwkoop Nieuwkoopse Plassen', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuwkoop Lintbebouwing', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuwkoop Buitengebied West', 'woz': '.'}
# {'year': '2024', 'regio': 'Bedrijventerrein Nieuwkoop', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuwkoop Buitengebied Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern De Meije', 'woz': '.'}
# {'year': '2024', 'regio': 'De Meije Nieuwkoopse Plassen', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Noorden', 'woz': '.'}
# {'year': '2024', 'regio': 'De Kuil', 'woz': '.'}
# {'year': '2024', 'regio': 'Noorden Lintbebouwing', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Noordse Dorp', 'woz': '.'}
# {'year': '2024', 'regio': 'Noordse Dorp', 'woz': '.'}
# {'year': '2024', 'regio': 'Noordse Buurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Woerdense Verlaat', 'woz': '.'}
# {'year': '2024', 'regio': 'Woerdense Verlaat', 'woz': '.'}
# {'year': '2024', 'regio': 'Achttienhoven', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Zevenhoven', 'woz': '.'}
# {'year': '2024', 'regio': 'Zevenhoven', 'woz': '.'}
# {'year': '2024', 'regio': 'Zevenhoven Buitengebied Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Zevenhoven Buitengebied West', 'woz': '.'}
# {'year': '2024', 'regio': 'Zevenhoven Recreatiegebied', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Noordeinde', 'woz': '.'}
# {'year': '2024', 'regio': 'Noordeinde', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Vrouwenakker', 'woz': '.'}
# {'year': '2024', 'regio': 'Vrouwenakker', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Nieuwveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuwveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuwveen Buitengebied Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuwveen Buitengebied West', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuwveen Buitengebied Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuwveen Buitengebied Vrouwenakker', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuwveens Jaagpad', 'woz': '.'}
# {'year': '2024', 'regio': 'Schoterveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Schoterhoek', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Ter Aar', 'woz': '.'}
# {'year': '2024', 'regio': 'Ter Aar Buitengebied', 'woz': '.'}
# {'year': '2024', 'regio': 'Aardam West', 'woz': '.'}
# {'year': '2024', 'regio': 'Aardam Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Bovenland', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Korteraar', 'woz': '.'}
# {'year': '2024', 'regio': 'Korteraar', 'woz': '.'}
# {'year': '2024', 'regio': 'Korteraar Buitengebied Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Korteraar Buitengebied Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Langeraar', 'woz': '.'}
# {'year': '2024', 'regio': 'Langeraar', 'woz': '.'}
# {'year': '2024', 'regio': 'Langeraar Lintbebouwing', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Papenveer', 'woz': '.'}
# {'year': '2024', 'regio': 'Papenveer', 'woz': '.'}
# {'year': '2024', 'regio': 'Noord Kethel', 'woz': '.'}
# {'year': '2024', 'regio': 'Schieveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Schiebroek', 'woz': '.'}
# {'year': '2024', 'regio': 'Hillegersberg Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Zuidwijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Zuidplein', 'woz': '.'}
# {'year': '2024', 'regio': 'Zuiderpark', 'woz': '.'}
# {'year': '2024', 'regio': 'Botlek', 'woz': '.'}
# {'year': '2024', 'regio': 'Europoort', 'woz': '.'}
# {'year': '2024', 'regio': 'Deurne', 'woz': '.'}
# {'year': '2024', 'regio': 'De Vennen', 'woz': '.'}
# {'year': '2024', 'regio': 'Deurne Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Heilige Geest', 'woz': '.'}
# {'year': '2024', 'regio': 'Houtenhoek', 'woz': '.'}
# {'year': '2024', 'regio': 'Provinciebuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Stationsbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Vlier-Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Vlier-Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Walsberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide woningen bij Deurne', 'woz': '.'}
# {'year': '2024', 'regio': 'Zeilberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Bedrijventerrein De Bottel', 'woz': '.'}
# {'year': '2024', 'regio': 'Bedrijventerrein Kranenmortel', 'woz': '.'}
# {'year': '2024', 'regio': 'Bedrijventerrein Leemskuilen', 'woz': '.'}
# {'year': '2024', 'regio': 'Bedrijventerrein Rijt-West en Rijt-Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Heiakker', 'woz': '.'}
# {'year': '2024', 'regio': 'Heiakker-Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Heiakker-West', 'woz': '.'}
# {'year': '2024', 'regio': 'Koolhof', 'woz': '.'}
# {'year': '2024', 'regio': 'Koolhof-Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Koolhof-Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Sint Jozefparochie', 'woz': '.'}
# {'year': '2024', 'regio': 'Sint Jozefparochie-Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Sint Jozefparochie-West', 'woz': '.'}
# {'year': '2024', 'regio': 'Vlierden', 'woz': '.'}
# {'year': '2024', 'regio': 'Vlierden kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide woningen bij Vlierden', 'woz': '.'}
# {'year': '2024', 'regio': 'Liessel', 'woz': '.'}
# {'year': '2024', 'regio': 'Liessel kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide woningen bij Liessel', 'woz': '.'}
# {'year': '2024', 'regio': 'Neerkant', 'woz': '.'}
# {'year': '2024', 'regio': 'Neerkant kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide woningen bij Neerkant', 'woz': '.'}
# {'year': '2024', 'regio': 'Helenaveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Helenaveen kern', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide woningen bij Helenaveen', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Moergestel Noord-West', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Moergestel Noord-West', 'woz': '.'}
# {'year': '2024', 'regio': 'Pannenschuur', 'woz': '.'}
# {'year': '2024', 'regio': 'omg Pannenschuur Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'omg. Bej.Centrum/Molen', 'woz': '.'}
# {'year': '2024', 'regio': 'Heukelom', 'woz': '.'}
# {'year': '2024', 'regio': 'Heukelom', 'woz': '.'}
# {'year': '2024', 'regio': 'buitengebied Oisterwijk Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'buitengebied Oisterwijk Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'buitengebied de Logt', 'woz': '.'}
# {'year': '2024', 'regio': 'Klompven/Eikenven', 'woz': '.'}
# {'year': '2024', 'regio': 'omg. Klompven/Eikenven', 'woz': '.'}
# {'year': '2024', 'regio': 'Omg. Prinsessenbuurt', 'woz': '.'}
# {'year': '2024', 'regio': 'Omg. Klein Bungalowpark', 'woz': '.'}
# {'year': '2024', 'regio': 'Omg. Groot Bungalowpark/Hoefkens', 'woz': '.'}
# {'year': '2024', 'regio': 'Industriebegied Stokeind', 'woz': '.'}
# {'year': '2024', 'regio': 'Omg. Kloosterlaan', 'woz': '.'}
# {'year': '2024', 'regio': 'Omg. Oostelvoortjes', 'woz': '.'}
# {'year': '2024', 'regio': 'Omg. Achterbos/Papenakker', 'woz': '.'}
# {'year': '2024', 'regio': 't Westend', 'woz': '.'}
# {'year': '2024', 'regio': "omg. 't Seuverick", 'woz': '.'}
# {'year': '2024', 'regio': 'Bunders', 'woz': '.'}
# {'year': '2024', 'regio': 'omg. Europaln/Hondsbergseln', 'woz': '.'}
# {'year': '2024', 'regio': 'omg. Bunders', 'woz': '.'}
# {'year': '2024', 'regio': 'omg. Dotterpln/Wildemanstraat', 'woz': '.'}
# {'year': '2024', 'regio': 'Levenskerk', 'woz': '.'}
# {'year': '2024', 'regio': 'Omg. Bosweg/Heisteeg', 'woz': '.'}
# {'year': '2024', 'regio': 'Omg. Levenskerk/Boomgaard', 'woz': '.'}
# {'year': '2024', 'regio': 'Waterhoef', 'woz': '.'}
# {'year': '2024', 'regio': 'omg. Burghtweide', 'woz': '.'}
# {'year': '2024', 'regio': 'omg. Waterhoef', 'woz': '.'}
# {'year': '2024', 'regio': 'Industrieterrein Kerkhoven', 'woz': '.'}
# {'year': '2024', 'regio': 'Industrieterrein Laarakkers', 'woz': '.'}
# {'year': '2024', 'regio': 'omg. Petrus Kerk', 'woz': '.'}
# {'year': '2024', 'regio': 'omg. De Lind/Kerkstraat', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Moergestel Zuid-Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Moergestel Zuid-Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Oisterwijk Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Oisterwijk Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Dorp Haaren', 'woz': '.'}
# {'year': '2024', 'regio': 'Dorp Haaren', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Haaren', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Haaren', 'woz': '.'}
# {'year': '2024', 'regio': 'Sportterreinen Den Donk', 'woz': '.'}
# {'year': '2024', 'regio': 'Sportpark Den Donk', 'woz': '.'}
# {'year': '2024', 'regio': 'Someren dorp', 'woz': '.'}
# {'year': '2024', 'regio': 'Someren centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Loove', 'woz': '.'}
# {'year': '2024', 'regio': 'Waterdael I + II', 'woz': '.'}
# {'year': '2024', 'regio': 'Waterdael III', 'woz': '.'}
# {'year': '2024', 'regio': 'Groote Hoeven', 'woz': '.'}
# {'year': '2024', 'regio': 'Lierop dorp', 'woz': '.'}
# {'year': '2024', 'regio': 'Lierop centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Gilde', 'woz': '.'}
# {'year': '2024', 'regio': 'Someren-Eind dorp', 'woz': '.'}
# {'year': '2024', 'regio': 'Someren-Eind centrum', 'woz': '.'}
# {'year': '2024', 'regio': 't Vaartje', 'woz': '.'}
# {'year': '2024', 'regio': 'Goede Vaart', 'woz': '.'}
# {'year': '2024', 'regio': 'Someren-Heide dorp', 'woz': '.'}
# {'year': '2024', 'regio': 'Someren-Heide centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Someren', 'woz': '.'}
# {'year': '2024', 'regio': 'Half Elfje', 'woz': '.'}
# {'year': '2024', 'regio': 'Ambachten', 'woz': '.'}
# {'year': '2024', 'regio': 'Slieven', 'woz': '.'}
# {'year': '2024', 'regio': 'De Hoof', 'woz': '.'}
# {'year': '2024', 'regio': 't Ven', 'woz': '.'}
# {'year': '2024', 'regio': 'Hoeven', 'woz': '.'}
# {'year': '2024', 'regio': 'Potakker', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Lierop', 'woz': '.'}
# {'year': '2024', 'regio': 'Boomen', 'woz': '.'}
# {'year': '2024', 'regio': 'Vaarsche Hoef', 'woz': '.'}
# {'year': '2024', 'regio': 'Lieropse Heide', 'woz': '.'}
# {'year': '2024', 'regio': 'Stipdonk', 'woz': '.'}
# {'year': '2024', 'regio': 'Lungendonk', 'woz': '.'}
# {'year': '2024', 'regio': 'Gebergte', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Someren-Eind', 'woz': '.'}
# {'year': '2024', 'regio': 'Blank Water', 'woz': '.'}
# {'year': '2024', 'regio': 'Vlas', 'woz': '.'}
# {'year': '2024', 'regio': 'Ravel', 'woz': '.'}
# {'year': '2024', 'regio': 'Sluis 12 / 13', 'woz': '.'}
# {'year': '2024', 'regio': 'Diepenhoek', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Someren-Heide', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Someren-Heide', 'woz': '.'}
# {'year': '2024', 'regio': 'Somerense Heide', 'woz': '.'}
# {'year': '2024', 'regio': 'Hugten', 'woz': '.'}
# {'year': '2024', 'regio': 'Boksenberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Susteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Handelsterrein', 'woz': '.'}
# {'year': '2024', 'regio': 'Middelveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Susteren Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Susteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Mariaveld', 'woz': '.'}
# {'year': '2024', 'regio': 'In de Mehre', 'woz': '.'}
# {'year': '2024', 'regio': 'Wolfskoul', 'woz': '.'}
# {'year': '2024', 'regio': 'Baakhoven', 'woz': '.'}
# {'year': '2024', 'regio': 'Munsterveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Dieteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Dieteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Dieteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Heide', 'woz': '.'}
# {'year': '2024', 'regio': 'Recreatiepark Hommelheide', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Heide', 'woz': '.'}
# {'year': '2024', 'regio': 'Heide', 'woz': '.'}
# {'year': '2024', 'regio': 'Illikhoven/Visserweert', 'woz': '.'}
# {'year': '2024', 'regio': 'Kokkelert', 'woz': '.'}
# {'year': '2024', 'regio': 'Roosteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Illikhoven/Visserweert', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Roosteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Echt', 'woz': '.'}
# {'year': '2024', 'regio': 'Aasterberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Berkelaar', 'woz': '.'}
# {'year': '2024', 'regio': 'De Berk', 'woz': '.'}
# {'year': '2024', 'regio': 'De Loop', 'woz': '.'}
# {'year': '2024', 'regio': 'Echt Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Echt Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Gebroek', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied De Berk', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied De Loop', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Gebroek', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Ophoven', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Berkelaar', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Aasterberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Businesspark Midden-Limburg', 'woz': '.'}
# {'year': '2024', 'regio': 'Echt Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Maria Hoop', 'woz': '.'}
# {'year': '2024', 'regio': 'Diergaarde', 'woz': '.'}
# {'year': '2024', 'regio': 'Echterbosch', 'woz': '.'}
# {'year': '2024', 'regio': 'Maria Hoop', 'woz': '.'}
# {'year': '2024', 'regio': 'Peij', 'woz': '.'}
# {'year': '2024', 'regio': 'Hingen', 'woz': '.'}
# {'year': '2024', 'regio': 'Peij', 'woz': '.'}
# {'year': '2024', 'regio': 'Peijerveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Recreatiepark Marisheem', 'woz': '.'}
# {'year': '2024', 'regio': 'Schilberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Hingen', 'woz': '.'}
# {'year': '2024', 'regio': 'Slek', 'woz': '.'}
# {'year': '2024', 'regio': 'Lilboscherveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Slek', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Nieuwstadt', 'woz': '.'}
# {'year': '2024', 'regio': 'Nieuwstadt Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Cristinawijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Sint Joost', 'woz': '.'}
# {'year': '2024', 'regio': 'Sint Joost', 'woz': '.'}
# {'year': '2024', 'regio': 'Verspreide huizen Sint Joost', 'woz': '.'}
# {'year': '2024', 'regio': 'Koningsbosch', 'woz': '.'}
# {'year': '2024', 'regio': 'Koningsbosch', 'woz': '.'}
# {'year': '2024', 'regio': 'Lackerbosch', 'woz': '.'}
# {'year': '2024', 'regio': 'Spaanshuisken', 'woz': '.'}
# {'year': '2024', 'regio': 'Aan het Echterbosch', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Spaanshuisken', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Elst', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Elst Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Reeth', 'woz': '.'}
# {'year': '2024', 'regio': 'Elst-Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Lynden', 'woz': '.'}
# {'year': '2024', 'regio': 'Vosbergen', 'woz': '.'}
# {'year': '2024', 'regio': 'Huyekamp', 'woz': '.'}
# {'year': '2024', 'regio': 'de Zuiling', 'woz': '.'}
# {'year': '2024', 'regio': 'Westeraam', 'woz': '.'}
# {'year': '2024', 'regio': 'Groenoord', 'woz': '.'}
# {'year': '2024', 'regio': 'Oosterhout', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Oosterhout', 'woz': '.'}
# {'year': '2024', 'regio': 'De Park', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Oosterhout West', 'woz': '.'}
# {'year': '2024', 'regio': 'Slijk-Ewijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied de Danenberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Herveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Herveld Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Herveld', 'woz': '.'}
# {'year': '2024', 'regio': 'Andelst', 'woz': '.'}
# {'year': '2024', 'regio': 'Bedrijventerrein Andelst Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Andelst', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Andelst', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Zetten', 'woz': '.'}
# {'year': '2024', 'regio': 'Zetten Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Zetten Noord-Magdalena', 'woz': '.'}
# {'year': '2024', 'regio': 'Omg. Sterappel, Loohof en Zetten Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Omg. Vluchtheuvellaan', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Zetten', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Zetten Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Randwijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Randwijk', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Heteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Melkweide', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Heteren', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Heteren Boterhoek-Weerbroek', 'woz': '.'}
# {'year': '2024', 'regio': 'Valburg', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Valburg Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Molenzicht', 'woz': '.'}
# {'year': '2024', 'regio': 'De Weem', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied De Meilanden', 'woz': '.'}
# {'year': '2024', 'regio': 'Kern Valburg', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Driel Keulse Kamp-GrietenKamp-Leedjes', 'woz': '.'}
# {'year': '2024', 'regio': 'Driel Zuid oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Virehof', 'woz': '.'}
# {'year': '2024', 'regio': 'Homoet', 'woz': '.'}
# {'year': '2024', 'regio': 'Geldrop', 'woz': '.'}
# {'year': '2024', 'regio': 'Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Skandia', 'woz': '.'}
# {'year': '2024', 'regio': 'Akert', 'woz': '.'}
# {'year': '2024', 'regio': 'Zesgehuchten', 'woz': '.'}
# {'year': '2024', 'regio': 'Braakhuizen-Noord', 'woz': '.'}
# {'year': '2024', 'regio': 'Braakhuizen-Zuid', 'woz': '.'}
# {'year': '2024', 'regio': 'Coevering', 'woz': '.'}
# {'year': '2024', 'regio': 'Genoenhuis', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Geldrop-Oost', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Geldrop- West', 'woz': '.'}
# {'year': '2024', 'regio': 'Mierlo', 'woz': '.'}
# {'year': '2024', 'regio': 'Mierlo-Dorp', 'woz': '.'}
# {'year': '2024', 'regio': 'Neerakkers', 'woz': '.'}
# {'year': '2024', 'regio': 'Kerkakkers', 'woz': '.'}
# {'year': '2024', 'regio': 'Luchen', 'woz': '.'}
# {'year': '2024', 'regio': 'Buitengebied Mierlo', 'woz': '.'}
# {'year': '2024', 'regio': 'Wijk 10 Denekamp', 'woz': '.'}
# {'year': '2024', 'regio': 'Centrum', 'woz': '.'}
# {'year': '2024', 'regio': 'Kerkeres', 'woz': '.'}
# {'year': '2024', 'regio': 'Klokkenberg', 'woz': '.'}
# {'year': '2024', 'regio': 'Dorper-Es', 'woz': '.'}
# {'year': '2024', 'regio': 'Veldkamp en Borchert', 'woz': '.'}
# {'year': '2024', 'regio': 'Janskamp', 'woz': '.'}
# ...
# {'year': '2023', 'regio': 'Schagen-Noord', 'woz': 289}
# {'year': '2023', 'regio': 'Bedrijventerrein Delftech', 'woz': '.'}
# {'year': '2023', 'regio': 'Schoemakerplantage', 'woz': 268}
# {'year': '2023', 'regio': "'s-Gravenhage", 'woz': 354}
# {'year': '2023', 'regio': 'Wijk 39 Binckhorst', 'woz': 301}
# {'year': '2023', 'regio': 'Binckhorst', 'woz': 301}
# {'year': '2023', 'regio': 'Wijk 41 Hoornwijk', 'woz': 416}
# {'year': '2023', 'regio': 'Vlietzoom-West', 'woz': 695}
# {'year': '2023', 'regio': 'Wijk 00', 'woz': 389}
# {'year': '2023', 'regio': 'Kerkwijk', 'woz': 535}
# {'year': '2023', 'regio': 'Ouderzorg', 'woz': 404}
# {'year': '2023', 'regio': 'Zijlkwartier', 'woz': 349}
# {'year': '2023', 'regio': 'De Vogelwijk', 'woz': 367}
# {'year': '2023', 'regio': 'De Baanderij', 'woz': 238}
# {'year': '2023', 'regio': 'Schansen en Dreven', 'woz': 322}
# {'year': '2023', 'regio': 'Winkelhof', 'woz': 289}
# {'year': '2023', 'regio': 'Binnenhof', 'woz': 439}
# {'year': '2023', 'regio': 'Voorhof', 'woz': 380}
# {'year': '2023', 'regio': 'Elisabethhof', 'woz': 527}
# {'year': '2023', 'regio': 'De Bloemerd', 'woz': '.'}
# {'year': '2023', 'regio': 'Wijk 01', 'woz': 508}
# {'year': '2023', 'regio': 'Oranjewijk', 'woz': 441}
# {'year': '2023', 'regio': 'Doeskwartier', 'woz': 410}
# {'year': '2023', 'regio': 't Heerlijk Recht', 'woz': 998}
# {'year': '2023', 'regio': 'Buitengebied', 'woz': 571}
# {'year': '2023', 'regio': 'Wijk 02', 'woz': 427}
# {'year': '2023', 'regio': 'Boterhuispolder', 'woz': '.'}
# {'year': '2023', 'regio': 'Buitenhof-Oost-Zuid', 'woz': 329}
# {'year': '2023', 'regio': 'Buitenhof-Midden-West', 'woz': 437}
# {'year': '2023', 'regio': 'Leyhof', 'woz': 489}
# {'year': '2023', 'regio': 'Driegatenbrug', 'woz': 564}
# {'year': '2023', 'regio': 'Witte Dorp', 'woz': 249}
# {'year': '2023', 'regio': 'Strand en Duin', 'woz': '.'}
# {'year': '2023', 'regio': 'Dorp', 'woz': 320}
# {'year': '2023', 'regio': 'Rijswijk', 'woz': 346}
# {'year': '2023', 'regio': 'Wijk 01', 'woz': 502}
# {'year': '2023', 'regio': 'Cromvliet', 'woz': 372}
# {'year': '2023', 'regio': 'Leeuwendaal', 'woz': 633}
# {'year': '2023', 'regio': 'Wijk 00 Centrum', 'woz': 315}
# {'year': '2023', 'regio': 'Binnenstad', 'woz': 279}
# {'year': '2023', 'regio': 'Brandersbuurt', 'woz': 283}
# {'year': '2023', 'regio': 'Walvisbuurt', 'woz': 337}
# {'year': '2023', 'regio': 'De Plantage', 'woz': 422}
# {'year': '2023', 'regio': 'Wijk 01 Oost', 'woz': 240}
# {'year': '2023', 'regio': 'Stadserf', 'woz': 269}
# {'year': '2023', 'regio': 'Natuurkundigenbuurt', 'woz': 242}
# {'year': '2023', 'regio': 'Singelkwartier', 'woz': 249}
# {'year': '2023', 'regio': 'Stationsbuurt', 'woz': 263}
# {'year': '2023', 'regio': 'Wetenschappersbuurt', 'woz': 288}
# {'year': '2023', 'regio': 'Newtonbuurt', 'woz': 225}
# {'year': '2023', 'regio': 'Boylebuurt', 'woz': 209}
# {'year': '2023', 'regio': 'Glasbuurt', 'woz': 215}
# {'year': '2023', 'regio': 'Marconibuurt', 'woz': 239}
# {'year': '2023', 'regio': 'Parallelbuurt', 'woz': '.'}
# {'year': '2023', 'regio': 'Schieveste', 'woz': '.'}
# {'year': '2023', 'regio': 'Wijk 02 Schiedamse Havens', 'woz': '.'}
# {'year': '2023', 'regio': 'Vijfsluizen', 'woz': '.'}
# {'year': '2023', 'regio': 'Wilhelminahaven', 'woz': '.'}
# {'year': '2023', 'regio': 'Nieuw-Mathenesse', 'woz': '.'}
# {'year': '2023', 'regio': 'Wijk 03 West', 'woz': 305}
# {'year': '2023', 'regio': 'Schildersbuurt', 'woz': 251}
# {'year': '2023', 'regio': 'Schrijversbuurt', 'woz': 270}
# {'year': '2023', 'regio': 'Fabribuurt', 'woz': 235}
# {'year': '2023', 'regio': 'Frankenland', 'woz': '.'}
# {'year': '2023', 'regio': 'Liduinabuurt', 'woz': 347}
# {'year': '2023', 'regio': 'Nassaukwartier', 'woz': 397}
# {'year': '2023', 'regio': 'Oranjekwartier', 'woz': 536}
# {'year': '2023', 'regio': 'Haverschmidtkwartier', 'woz': 363}
# {'year': '2023', 'regio': 'Distillateursbuurt', 'woz': 316}
# {'year': '2023', 'regio': 'Park Vijfsluizen', 'woz': '.'}
# {'year': '2023', 'regio': 'Wijk 04 Zuid', 'woz': 249}
# {'year': '2023', 'regio': 'Noletbuurt', 'woz': 233}
# {'year': '2023', 'regio': 'Eilandenbuurt', 'woz': 228}
# {'year': '2023', 'regio': 'Sandersbuurt', 'woz': 252}
# {'year': '2023', 'regio': 'Maasboulevard', 'woz': 314}
# {'year': '2023', 'regio': 'Wijk 05 Kethel', 'woz': 421}
# {'year': '2023', 'regio': 'Kethel-dorp', 'woz': 348}
# {'year': '2023', 'regio': 'Zwaluwbuurt', 'woz': 424}
# {'year': '2023', 'regio': 'Tuindorp', 'woz': 391}
# {'year': '2023', 'regio': 'Bijdorp', 'woz': 301}
# {'year': '2023', 'regio': 'Harga', 'woz': 532}
# {'year': '2023', 'regio': 'Beatrixpark', 'woz': '.'}
# {'year': '2023', 'regio': 'Sportpark Harga', 'woz': '.'}
# {'year': '2023', 'regio': 'Wijk 06 Nieuwland', 'woz': 242}
# {'year': '2023', 'regio': 'Troelstrabuurt', 'woz': 198}
# {'year': '2023', 'regio': 'Spieringshoek', 'woz': 255}
# {'year': '2023', 'regio': 'Staatsliedenbuurt', 'woz': 236}
# {'year': '2023', 'regio': 'Vakbondsliedenbuurt', 'woz': 335}
# {'year': '2023', 'regio': 'Hollandiabuurt', 'woz': 248}
# {'year': '2023', 'regio': 'Schiehart', 'woz': 309}
# {'year': '2023', 'regio': 'Nolensbuurt', 'woz': 213}
# {'year': '2023', 'regio': 'De Meesterbuurt', 'woz': '.'}
# {'year': '2023', 'regio': 'Cartonnagebuurt', 'woz': 216}
# {'year': '2023', 'regio': 'Wibautbuurt', 'woz': 226}
# {'year': '2023', 'regio': 'Wijk 07 Groenoord', 'woz': 229}
# {'year': '2023', 'regio': 'Van Beethovenbuurt', 'woz': 227}
# {'year': '2023', 'regio': 'Groenoord-Zuid', 'woz': 204}
# {'year': '2023', 'regio': 'Van Zantenbuurt', 'woz': 231}
# {'year': '2023', 'regio': 'Mozartbuurt', 'woz': 252}
# {'year': '2023', 'regio': 'Groenoord-Noord', 'woz': 229}
# {'year': '2023', 'regio': 'Bachplein', 'woz': 227}
# {'year': '2023', 'regio': 'Wijk 08 Industrie', 'woz': '.'}
# {'year': '2023', 'regio': 'Spaanse Polder', 'woz': '.'}
# {'year': '2023', 'regio': 's-Graveland', 'woz': '.'}
# {'year': '2023', 'regio': 'Wijk 09 Woudhoek', 'woz': 312}
# {'year': '2023', 'regio': 'Toneelspelersbuurt', 'woz': 296}
# {'year': '2023', 'regio': 'Ambachtenbuurt', 'woz': 314}
# {'year': '2023', 'regio': 'Kastelenbuurt', 'woz': 325}
# {'year': '2023', 'regio': 'Botenbuurt', 'woz': 311}
# {'year': '2023', 'regio': 'Wijk 10 Spaland en Sveaparken', 'woz': 405}
# {'year': '2023', 'regio': 'De Gaarden en Windas', 'woz': 376}
# {'year': '2023', 'regio': 'De Vlinderhoven', 'woz': 378}
# {'year': '2023', 'regio': 'De Akkers', 'woz': 361}
# {'year': '2023', 'regio': 'De Velden', 'woz': 371}
# {'year': '2023', 'regio': 'Sveaborg en Sveadal', 'woz': 460}
# {'year': '2023', 'regio': 'Sveaholm', 'woz': 505}
# {'year': '2023', 'regio': 'Sveafors', 'woz': 494}
# {'year': '2023', 'regio': 'Wijk 11 Polderbuitengebied', 'woz': 640}
# {'year': '2023', 'regio': 'Noordkethelpolder', 'woz': 1104}
# {'year': '2023', 'regio': 'Polderwetering', 'woz': 579}
# {'year': '2023', 'regio': 'Noord-Hofland', 'woz': 418}
# {'year': '2023', 'regio': 'Adegeest', 'woz': 473}
# {'year': '2023', 'regio': 'Boschgeest', 'woz': 571}
# {'year': '2023', 'regio': 'Bijdorp', 'woz': 454}
# {'year': '2023', 'regio': 'Vlietwijk', 'woz': 341}
# {'year': '2023', 'regio': 'Starrenburg', 'woz': 607}
# {'year': '2023', 'regio': 'Dobbewijk', 'woz': 444}
# {'year': '2023', 'regio': 'Krimwijk', 'woz': 695}
# {'year': '2023', 'regio': 'Centrum', 'woz': 394}
# {'year': '2023', 'regio': 'Nassauwijk', 'woz': 552}
# {'year': '2023', 'regio': 'Bloemenwijk', 'woz': 525}
# {'year': '2023', 'regio': 'Buitengebied', 'woz': 804}
# {'year': '2023', 'regio': 'Nieuw Namen', 'woz': 277}
# {'year': '2023', 'regio': 'Buitengebied Nieuw Namen', 'woz': 367}
# {'year': '2023', 'regio': 'Kloosterzande', 'woz': 247}
# {'year': '2023', 'regio': 'Buitengebied Kloosterzande', 'woz': 301}
# {'year': '2023', 'regio': 'Walsoorden', 'woz': 273}
# {'year': '2023', 'regio': 'Kern Walsoorden', 'woz': 246}
# {'year': '2023', 'regio': 'Perkpolder', 'woz': '.'}
# {'year': '2023', 'regio': 'Buitengebied Walsoorden', 'woz': 295}
# {'year': '2023', 'regio': 'Binnenstad', 'woz': 189}
# {'year': '2023', 'regio': 'Oude Binnenstad', 'woz': 211}
# {'year': '2023', 'regio': 'Paauwenburg - Westduin', 'woz': 273}
# {'year': '2023', 'regio': 'Westduin', 'woz': '.'}
# {'year': '2023', 'regio': 'Binnenstad', 'woz': 430}
# {'year': '2023', 'regio': 'Vughterpoort', 'woz': 1137}
# {'year': '2023', 'regio': 'Vlietdijk', 'woz': 297}
# {'year': '2023', 'regio': 'De Hoven', 'woz': 516}
# {'year': '2023', 'regio': 'De Lanen', 'woz': 522}
# {'year': '2023', 'regio': 'Centrum De Groote Wielen', 'woz': '.'}
# {'year': '2023', 'regio': 'Landelijk gebied De Groote Wielen', 'woz': '.'}
# {'year': '2023', 'regio': 'West', 'woz': 322}
# {'year': '2023', 'regio': 'Willemspoort', 'woz': 484}
# {'year': '2023', 'regio': 'Kom Nuland', 'woz': 429}
# {'year': '2023', 'regio': 'De Lage Kant', 'woz': 660}
# {'year': '2023', 'regio': 'Centrum', 'woz': 318}
# {'year': '2023', 'regio': 'Besoyen', 'woz': 332}
# {'year': '2023', 'regio': 'Bloemenoord', 'woz': 255}
# {'year': '2023', 'regio': 'Zanddonk', 'woz': 307}
# {'year': '2023', 'regio': 'Meerdijk', 'woz': 563}
# {'year': '2023', 'regio': 'Industrieterrein Haven', 'woz': '.'}
# {'year': '2023', 'regio': 'Buitengebied Waalwijk Noord', 'woz': '.'}
# {'year': '2023', 'regio': 'Eikendonk', 'woz': '.'}
# {'year': '2023', 'regio': 'Recreatieoord', 'woz': '.'}
# {'year': '2023', 'regio': 'Sprang', 'woz': 387}
# {'year': '2023', 'regio': 'Landgoed Driessen', 'woz': 385}
# {'year': '2023', 'regio': 'Wijk 00 Gemert-Centrum', 'woz': 359}
# {'year': '2023', 'regio': 'Wijk 01 Gemert-Noord', 'woz': 371}
# {'year': '2023', 'regio': 'Wijk 02 Gemert-Oost', 'woz': 360}
# {'year': '2023', 'regio': 'Steenwijk', 'woz': 258}
# {'year': '2023', 'regio': 'Dolderkanaal', 'woz': '.'}
# {'year': '2023', 'regio': 'Tuk', 'woz': 363}
# {'year': '2023', 'regio': 'Tuk', 'woz': 359}
# {'year': '2023', 'regio': 'Wijk 00 Stad Rijssen', 'woz': 329}
# {'year': '2023', 'regio': 'Kern-Rijssen', 'woz': 286}
# {'year': '2023', 'regio': 'Het Molenstal', 'woz': 357}
# {'year': '2023', 'regio': 'Hagslagen', 'woz': 369}
# {'year': '2023', 'regio': 'Stad West', 'woz': 373}
# {'year': '2023', 'regio': 'Kern rand Noord', 'woz': 358}
# {'year': '2023', 'regio': 'Hofstee en De Delle', 'woz': 292}
# {'year': '2023', 'regio': 'Wijk 02 Buitengebied Rijssen', 'woz': 559}
# {'year': '2023', 'regio': 'Verspreide huizen Ligtenberg', 'woz': 518}
# {'year': '2023', 'regio': 'Verspreide huizen Zuidrand en omgeving', 'woz': 532}
# {'year': '2023', 'regio': 'Wijk 03 Holten', 'woz': 371}
# {'year': '2023', 'regio': 'Holten-De Haar', 'woz': 285}
# {'year': '2023', 'regio': 'Holten ten noorden van de spoorlijn', 'woz': 423}
# {'year': '2023', 'regio': 'De Holterberg', 'woz': 940}
# {'year': '2023', 'regio': 'Villaterrein De Look', 'woz': 826}
# {'year': '2023', 'regio': 'Lukensveld', 'woz': 434}
# {'year': '2023', 'regio': 'Holten-Kom', 'woz': 314}
# {'year': '2023', 'regio': 'De Kol en Noordenberg', 'woz': 344}
# {'year': '2023', 'regio': 'Wijk 04 Bedrijventerrein Holten', 'woz': '.'}
# {'year': '2023', 'regio': 'Industrieterrein de Haar', 'woz': '.'}
# {'year': '2023', 'regio': 'Vletgaarsmaten', 'woz': '.'}
# {'year': '2023', 'regio': 'Wijk 05 Buitengebied Holten', 'woz': 462}
# {'year': '2023', 'regio': 'Buurtschap Neerdorp', 'woz': 499}
# {'year': '2023', 'regio': 'Buurtschap Holterbroek', 'woz': 490}
# {'year': '2023', 'regio': 'Buurtschap Beuseberg', 'woz': 453}
# {'year': '2023', 'regio': 'Buurtschap Espelo', 'woz': 434}
# {'year': '2023', 'regio': 'Buurtschap Borkeld', 'woz': 434}
# {'year': '2023', 'regio': 'Buurtschap Look', 'woz': 477}
# {'year': '2023', 'regio': 'Buurtschap Holterberg', 'woz': '.'}
# {'year': '2023', 'regio': 'Buurtschap Lichtenberg', 'woz': '.'}
# {'year': '2023', 'regio': 'Dijkerhoek kern', 'woz': 423}
# {'year': '2023', 'regio': 'Verspreide huizen Dijkerhoek', 'woz': 459}
# {'year': '2023', 'regio': 'Wijk 07 Bedrijventerrein Rijssen', 'woz': 368}
# {'year': '2023', 'regio': 'De Mors en Plaagslagen', 'woz': 368}
# {'year': '2023', 'regio': 'Wijk 08 Recreatiegebied De Borkeld', 'woz': 431}
# {'year': '2023', 'regio': 'Zomerhuisjesterrein De Borkeld', 'woz': 431}
# {'year': '2023', 'regio': 'Wijk 09 Stadsrand Rijssen Noord', 'woz': 397}
# {'year': '2023', 'regio': 'Veeneslagen Oost', 'woz': 374}
# {'year': '2023', 'regio': 'Veeneslagen West', 'woz': 423}
# {'year': '2023', 'regio': 'Dannenberg', 'woz': 375}
# {'year': '2023', 'regio': 'Wijk 10 Stadsrand Rijssen Zuid', 'woz': 295}
# {'year': '2023', 'regio': 'Braakmanslanden midden', 'woz': 358}
# {'year': '2023', 'regio': 'Braakmanslanden noordoost', 'woz': 245}
# {'year': '2023', 'regio': 'Braakmanslanden zuidwest', 'woz': '.'}
# {'year': '2023', 'regio': 'De Lage Es', 'woz': 318}
# {'year': '2023', 'regio': 'Nieuwland en Lentfert', 'woz': 281}
# {'year': '2023', 'regio': 'Plan Zuid', 'woz': 308}
# {'year': '2023', 'regio': 'De Welle', 'woz': 273}
# {'year': '2023', 'regio': 'Wijk 11 Stadsrand Rijssen Oost', 'woz': 396}
# {'year': '2023', 'regio': 'Het Opbroek zuid', 'woz': 438}
# {'year': '2023', 'regio': 'Het Opbroek noord', 'woz': 584}
# {'year': '2023', 'regio': 'Stokmansveld en De Waterhoek', 'woz': 608}
# {'year': '2023', 'regio': 'Hangerad en Oosterhofesch', 'woz': 293}
# {'year': '2023', 'regio': 'Buitengebied 2 Naaldwijk', 'woz': 835}
# {'year': '2023', 'regio': 'Buitengebied 1 Naaldwijk', 'woz': 751}
# {'year': '2023', 'regio': 'Buitengebied 3 Naaldwijk', 'woz': 511}
# {'year': '2023', 'regio': 'Buitengebied 2 wateringen', 'woz': 665}
# {'year': '2023', 'regio': 'Buitengebied 1 wateringen', 'woz': 628}
# {'year': '2023', 'regio': 'Buitengebied 1 De Lier', 'woz': 601}
# {'year': '2023', 'regio': 'Buitengebied 2 De Lier', 'woz': 787}
# {'year': '2023', 'regio': 'Tolhek', 'woz': 488}
# {'year': '2023', 'regio': 'Ackerswoude', 'woz': 675}
# {'year': '2023', 'regio': 'Tuindershof', 'woz': 505}
# {'year': '2023', 'regio': 'Zuidpolder Oude Leede', 'woz': 650}
# {'year': '2023', 'regio': 'Pijnacker Oost', 'woz': 767}
# {'year': '2023', 'regio': 'De Scheg', 'woz': 578}
# {'year': '2023', 'regio': 'Tolhek Centrumlijn', 'woz': 365}
# {'year': '2023', 'regio': 'Zuidpolder Delfgauw', 'woz': 686}
# {'year': '2023', 'regio': 'Gooise Meren', 'woz': 559}
# {'year': '2023', 'regio': 'Eng', 'woz': 439}
# {'year': '2023', 'regio': 'Ooster Eng-Zuid', 'woz': 390}
# {'year': '2023', 'regio': 'Spiegel', 'woz': 916}
# {'year': '2023', 'regio': 'Boslaan', 'woz': 1218}
# {'year': '2023', 'regio': 'Fransekamp', 'woz': 1442}
# {'year': '2023', 'regio': 'St.-Annaparochie', 'woz': 228}
# {'year': '2023', 'regio': 'Buitengebied St.-Annaparochie', 'woz': 293}
# {'year': '2023', 'regio': 'St.-Jacobiparochie', 'woz': 212}
# {'year': '2023', 'regio': 'Buitengebied St.-Jacobiparochie', 'woz': 269}
# {'year': '2023', 'regio': 'Uden', 'woz': 363}
# {'year': '2023', 'regio': 'Centrum', 'woz': 272}
# {'year': '2023', 'regio': 'Bogerd-Vijfhuis', 'woz': 334}
# {'year': '2023', 'regio': 'Moleneind-Groenewoud', 'woz': 438}
# {'year': '2023', 'regio': 'Flatwijk', 'woz': 187}
# {'year': '2023', 'regio': 'Bitswijk', 'woz': 320}
# {'year': '2023', 'regio': 'Hoevenseveld', 'woz': 319}
# {'year': '2023', 'regio': 'Schutveld', 'woz': 460}
# {'year': '2023', 'regio': 'Buurtschap Hoeven', 'woz': 814}
# {'year': '2023', 'regio': 'Hoeven', 'woz': 443}
# {'year': '2023', 'regio': 'Melle', 'woz': 307}
# {'year': '2023', 'regio': 'Raam', 'woz': 356}
# {'year': '2023', 'regio': 'Sportpark Volkelseweg', 'woz': 230}
# {'year': '2023', 'regio': 'Zoggel', 'woz': 399}
# {'year': '2023', 'regio': 'Vluchtoord', 'woz': 364}
# {'year': '2023', 'regio': 'Loopkant-Liessent-Goorkens', 'woz': 381}
# {'year': '2023', 'regio': 'Hoenderbos-Velmolen', 'woz': 447}
# {'year': '2023', 'regio': 'Eikenheuvel', 'woz': 593}
# {'year': '2023', 'regio': 'Buitengebied Uden-Oost', 'woz': 646}
# {'year': '2023', 'regio': 'Buitengebied Uden-Zuid', 'woz': 633}
# {'year': '2023', 'regio': 'Buitengebied Uden-West', 'woz': 540}
# {'year': '2023', 'regio': 'Buitengebied Maashorst', 'woz': 636}
# {'year': '2023', 'regio': 'Volkel', 'woz': 425}
# {'year': '2023', 'regio': 'Kom Volkel', 'woz': 375}
# {'year': '2023', 'regio': 'Vliegbasis Volkel', 'woz': '.'}
# {'year': '2023', 'regio': 'Buitengebied-Volkel', 'woz': 547}
# {'year': '2023', 'regio': 'Odiliapeel', 'woz': 411}
# {'year': '2023', 'regio': 'Odiliapeel', 'woz': 376}
# {'year': '2023', 'regio': 'Buitengebied-Odiliapeel', 'woz': 518}
# {'year': '2023', 'regio': 'Voorne aan Zee', 'woz': 369}

# %%
len(list3)
df_24 = pd.read_excel('kwb-2024.xls')

# %%
print(len(df_24))
# Out:
# 18310
